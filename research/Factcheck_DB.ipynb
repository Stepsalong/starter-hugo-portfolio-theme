# %% [markdown]
# <a href="https://colab.research.google.com/github/Stepsalong/starter-hugo-portfolio-theme/blob/main/research/Factcheck_DB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fact-checking database for dokopalsya.bot

# %% [markdown]
# The goal of this notebook is to set up a fact-checking database ready to be used on the hackathon to building a fact checking bot.
#
# Plan -
# 1. Build a sustainable data retrieval pipeline from the google fact check api
# 2. Set-up the ETL in place to ensure high quality data flowing into pinecone
# 3. Choose the best embedding model
# 4. Using this model load the data into pinecone

# %% [markdown]
# ## Set-up - Packages, Libraries & Functions

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.11)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.27.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
# !pip install pinecone
# Out:
# Requirement already satisfied: pinecone in /usr/local/lib/python3.11/dist-packages (5.4.2)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.11/dist-packages (from pinecone) (2024.12.14)
# Requirement already satisfied: pinecone-plugin-inference<4.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pinecone) (3.1.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from pinecone) (2.8.2)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.11/dist-packages (from pinecone) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from pinecone) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from pinecone) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)

# %%
import pandas as pd
import json
import requests
from datetime import datetime
import time
from google.colab import files
from google.colab import drive
from sentence_transformers import SentenceTransformer
from pinecone import Pinecone, ServerlessSpec
from tqdm import tqdm
import numpy as np
import uuid

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## function to convert our scrapped json files to pandas dataframes

# %%
def json_to_dataframe(json_data):
    # Extract claims from the JSON
    claims = json_data.get("claims", [])

    # Combine main fields and claimReview for each claim
    combined_data = []
    for claim in claims:
        main_data = {
            "text": claim.get("text"),
            "claimant": claim.get("claimant"),
            "claimDate": claim.get("claimDate")
        }
        for review in claim.get("claimReview", []):
            review_data = {
                "text": main_data["text"],
                "claimant": main_data["claimant"],
                "claimDate": main_data["claimDate"],
                "publisher_name": review.get("publisher", {}).get("name"),
                "publisher_site": review.get("publisher", {}).get("site"),
                "url": review.get("url"),
                "title": review.get("title"),
                "reviewDate": review.get("reviewDate"),
                "textualRating": review.get("textualRating"),
                "languageCode": review.get("languageCode")
            }
            combined_data.append(review_data)

    # Create a single DataFrame
    df = pd.DataFrame(combined_data)

    return df

# %%
# Define a function to check if a string is likely text
def is_likely_text(text):
  if not isinstance(text, str):
    return False
  if not text:  # Check for empty string
    return False
  if text.isdigit():  # Check if string contains only digits
    return False
  try:
      datetime.strptime(text, '%Y-%m-%d')  # Attempt to parse as date
      return False
  except ValueError:
      pass
  # Add more checks for other non-text patterns as needed
  return True

# %%
# API endpoint
url = "https://factchecktools.googleapis.com/v1alpha1/claims:search"

# API key
api_key = 'AIzaSyB7NjZt5iaKPMsOQuFwfecOkUByBBpq6Og'

# %%
pc = Pinecone(api_key="b97736e3-1462-49b6-921c-7e4412707993")

# %% [markdown]
# ## Dataset Retrieval

# %% [markdown]
# ### Dataset Retrieval API - Disabled!

# %%
# below is the result of our analysis - the list of the biggest factchecking sources verified by ICFN - international factcheking organisation

# %%
list_of_publishers = ['fullfact.org', 'snopes.com', 'newschecker.in',
       'factcheck.afp.com', 'factly.in', 'politifact.com',
       'factcheck.org', 'thequint.com',
       'vishvasnews.com', 'provereno.media', 'indiatoday.in',
       'newsmeter.in', 'science.feedback.org',
       'usatoday.com', 'en.youturn.in',
       'apnews.com', 'stopfake.org', 'leadstories.com',
       'checkyourfact.com', 'voxukraine.org', 'rappler.com',
       'srilanka.factcrescendo.com', 'africacheck.org',
       'logicallyfacts.com', 'aap.com.au', 'verafiles.org', 'boomlive.in']

# %%
# df_claims = pd.DataFrame()  # Creates a new empty DataFrame

# for publisher in list_of_publishers:
#   for language in ['uk', 'ru', 'en']:
#     # Query parameters
#     params = {
#         "maxAgeDays": 1095,
#         "pageSize": 10000,  # Set to max size for fewer paginated requests
#         "key": api_key,
#         "reviewPublisherSiteFilter": publisher,
#         "languageCode": language,
#     }

#     # Make initial request
#     response = requests.get(url, params=params)
#     response_data = response.json()
#     df = json_to_dataframe(response_data)
#     df['publisher_from_list'] = publisher
#     if len(df) > 0:  # Check if the DataFrame is not empty
#         df_claims = pd.concat([df_claims, df], ignore_index=True)

# %% [markdown]
# ### Dataset Retrieval CSV

# %%
# Load the Augmented CSV file from Google Drive
df_claims = pd.read_csv('/content/drive/MyDrive/Oplot/Connecthack/claims_en_ru_ua_last_3_years_augmented250125.csv')

# Now you can work with df_claims
print(df_claims.head())
# Out:
#    Unnamed: 0                                               text  \
# 0           0  Footage shows a tsunami after a recent earthqu...
# 1           1  A video shows Hamas fighters praying after the...
# 2           2  “Record numbers” of people have been returned ...
# 3           3  A video shows the perspective of a firefighter...
# 4           4  Bovaer reduces the fertility of cattle and poi...
#
#         claimant             claimDate publisher_name publisher_site  \
# 0         Pubilc  2026-01-14T00:00:00Z      Full Fact   fullfact.org
# 1  Facebook user  2025-01-15T00:00:00Z      Full Fact   fullfact.org
# 2   Keir Starmer  2025-01-09T00:00:00Z      Full Fact   fullfact.org
# 3         X User  2025-01-10T00:00:00Z      Full Fact   fullfact.org
# 4  facebook user  2025-01-10T00:00:00Z      Full Fact   fullfact.org
#
#                                                  url  \
# 0  https://fullfact.org/online/miscaptioned-foota...
# 1  https://fullfact.org/online/video-hamas-fighters/
# 2  https://fullfact.org/immigration/asylum-seeker...
# 3  https://fullfact.org/online/gopro-footage-fire...
# 4  https://fullfact.org/news/bovaer-meat-investin...
#
#                                                title            reviewDate  \
# 0  Footage of 2011 Japan tsunami being shared as ...  2025-01-17T00:00:00Z
# 1  Video of Hamas fighters is not recent – Full Fact  2025-01-17T00:00:00Z
# 2  Have 16,400 ‘failed asylum seekers’ been sent ...  2025-01-16T00:00:00Z
# 3  GoPro footage shows firefighter in Chile, not ...  2025-01-16T00:00:00Z
# 4  Bovaer has not been found to reduce cattle fer...  2025-01-16T00:00:00Z
#
#                                        textualRating languageCode  \
# 0  False. This clip shows a tsunami in the countr...           en
# 1  The video being shared is more than 17 years o...           en
# 2  This does not appear to be correct. The number...           en
# 3  Incorrect. This footage was first posted in No...           en
# 4  Bovaer has not been found to have any adverse ...           en
#
#   publisher_from_list                                        explanation  \
# 0        fullfact.org  A video from 2011 is being shared on social me...
# 1        fullfact.org  The video being shared is more than 17 years o...
# 2        fullfact.org  This does not appear to be correct. The number...
# 3        fullfact.org  Incorrect. This footage was first posted in No...
# 4        fullfact.org  This is correct. The company which manufacture...
#
#   simplified_textualRating                                            text_en
# 0                    false  Footage shows a tsunami after a recent earthqu...
# 1                      NaN  A video shows Hamas fighters praying after the...
# 2                      NaN  “Record numbers” of people have been returned ...
# 3                    false  A video shows the perspective of a firefighter...
# 4                      NaN  Bovaer reduces the fertility of cattle and poi...

# %%
# # link is publicly available
# url = "https://drive.google.com/uc?id=12ViKWF_1ammeN0nUW7mid6d1QBR6qXDc"
# try:
#     df_claims = pd.read_csv(url)
#     print("CSV file imported successfully!")
#     print(df_claims.head())
# except Exception as e:
#     print(f"An unexpected error occurred: {e}")
# Out:
# CSV file imported successfully!
#                             primary_key  \
# 0  dc6e9db4-4bd7-4f12-abba-da0c1a34868f
# 1  69c0271b-12a5-45ae-880c-7a943f83c41e
# 2  c0c1e0bf-b7d8-4ee5-bac7-90bca4e80ad1
# 3  ba1d8107-09d2-42da-8be7-5cae63d3c674
# 4  3219b40b-c3a5-4df2-b3a5-160a83b665fb
#
#                                                 text       claimant  \
# 0  A video shows Hamas fighters praying after the...  Facebook user
# 1  Footage shows a tsunami after a recent earthqu...         Pubilc
# 2  The manufacturer of Bovaer has also invested i...  facebook user
# 3  The government says 16,400 failed asylum seeke...  Daily Express
# 4  “Record numbers” of people have been returned ...   Keir Starmer
#
#               claimDate publisher_name publisher_site  \
# 0  2025-01-15T00:00:00Z      Full Fact   fullfact.org
# 1  2026-01-14T00:00:00Z      Full Fact   fullfact.org
# 2  2025-01-10T00:00:00Z      Full Fact   fullfact.org
# 3  2025-01-09T00:00:00Z      Full Fact   fullfact.org
# 4  2025-01-09T00:00:00Z      Full Fact   fullfact.org
#
#                                                  url  \
# 0  https://fullfact.org/online/video-hamas-fighters/
# 1  https://fullfact.org/online/miscaptioned-foota...
# 2  https://fullfact.org/news/bovaer-meat-investin...
# 3  https://fullfact.org/immigration/asylum-seeker...
# 4  https://fullfact.org/immigration/asylum-seeker...
#
#                                                title            reviewDate  \
# 0  Video of Hamas fighters is not recent – Full Fact  2025-01-17T00:00:00Z
# 1  Footage of 2011 Japan tsunami being shared as ...  2025-01-17T00:00:00Z
# 2  Bovaer has not been found to reduce cattle fer...  2025-01-16T00:00:00Z
# 3  Have 16,400 ‘failed asylum seekers’ been sent ...  2025-01-16T00:00:00Z
# 4  Have 16,400 ‘failed asylum seekers’ been sent ...  2025-01-16T00:00:00Z
#
#                                        textualRating languageCode  \
# 0  The video being shared is more than 17 years o...           en
# 1  False. This clip shows a tsunami in the countr...           en
# 2  This is correct. The company which manufacture...           en
# 3  We can’t find an example of the government say...           en
# 4  This does not appear to be correct. The number...           en
#
#   publisher_from_list
# 0        fullfact.org
# 1        fullfact.org
# 2        fullfact.org
# 3        fullfact.org
# 4        fullfact.org

# %%
df_claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52640 entries, 0 to 52639
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                52640 non-null  int64
#  1   text                      52640 non-null  object
#  2   claimant                  52640 non-null  object
#  3   claimDate                 47219 non-null  object
#  4   publisher_name            52640 non-null  object
#  5   publisher_site            52640 non-null  object
#  6   url                       52640 non-null  object
#  7   title                     52640 non-null  object
#  8   reviewDate                46033 non-null  object
#  9   textualRating             52640 non-null  object
#  10  languageCode              52640 non-null  object
#  11  publisher_from_list       52640 non-null  object
#  12  explanation               45615 non-null  object
#  13  simplified_textualRating  47754 non-null  object
#  14  text_en                   52640 non-null  object
# dtypes: int64(1), object(14)
# memory usage: 6.0+ MB

# %% [markdown]
# ## Dataset Quality Control

# %% [markdown]
# ### Prefiltering

# %%
## lets make sure that only major publishers in the required languages are present

# %%
df_claims = df_claims[df_claims['languageCode'].isin(['en', 'ru', 'uk'])]

# %%
publisher_counts = df_claims['publisher_site'].value_counts()

# Filter out publishers with less than 450 occurrences
publishers_to_keep = publisher_counts[publisher_counts >= 450].index

# Filter the original DataFrame
df_claims = df_claims[df_claims['publisher_site'].isin(publishers_to_keep)]

# Now filtered_df contains only the rows where the publisher_site appears at least 500 times.
len(df_claims)
# Out:
# 52640

# %% [markdown]
# ### Identification and removal of data of incorrect type

# %%
df_claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52640 entries, 0 to 52639
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                52640 non-null  int64
#  1   text                      52640 non-null  object
#  2   claimant                  52640 non-null  object
#  3   claimDate                 47219 non-null  object
#  4   publisher_name            52640 non-null  object
#  5   publisher_site            52640 non-null  object
#  6   url                       52640 non-null  object
#  7   title                     52640 non-null  object
#  8   reviewDate                46033 non-null  object
#  9   textualRating             52640 non-null  object
#  10  languageCode              52640 non-null  object
#  11  publisher_from_list       52640 non-null  object
#  12  explanation               45615 non-null  object
#  13  simplified_textualRating  47754 non-null  object
#  14  text_en                   52640 non-null  object
# dtypes: int64(1), object(14)
# memory usage: 6.0+ MB

# %%
str_columns_must_have = ['text', 'publisher_site', 'title', 'textualRating', 'languageCode']

# %%
for column in str_columns_must_have:
  # Instead of filtering, display rows that don't meet the criteria
  print(f"Rows in '{column}' that are not likely text:")
  print(df_claims[~df_claims[column].apply(is_likely_text)])
  print("-" * 50) # Separator for better readability
# Out:
# Rows in 'text' that are not likely text:
# Empty DataFrame
# Columns: [Unnamed: 0, text, claimant, claimDate, publisher_name, publisher_site, url, title, reviewDate, textualRating, languageCode, publisher_from_list, explanation, simplified_textualRating, text_en]
# Index: []
# --------------------------------------------------
# Rows in 'publisher_site' that are not likely text:
# Empty DataFrame
# Columns: [Unnamed: 0, text, claimant, claimDate, publisher_name, publisher_site, url, title, reviewDate, textualRating, languageCode, publisher_from_list, explanation, simplified_textualRating, text_en]
# Index: []
# --------------------------------------------------
# Rows in 'title' that are not likely text:
# Empty DataFrame
# Columns: [Unnamed: 0, text, claimant, claimDate, publisher_name, publisher_site, url, title, reviewDate, textualRating, languageCode, publisher_from_list, explanation, simplified_textualRating, text_en]
# Index: []
# --------------------------------------------------
# Rows in 'textualRating' that are not likely text:
# Empty DataFrame
# Columns: [Unnamed: 0, text, claimant, claimDate, publisher_name, publisher_site, url, title, reviewDate, textualRating, languageCode, publisher_from_list, explanation, simplified_textualRating, text_en]
# Index: []
# --------------------------------------------------
# Rows in 'languageCode' that are not likely text:
# Empty DataFrame
# Columns: [Unnamed: 0, text, claimant, claimDate, publisher_name, publisher_site, url, title, reviewDate, textualRating, languageCode, publisher_from_list, explanation, simplified_textualRating, text_en]
# Index: []
# --------------------------------------------------

# %%
for column in str_columns_must_have:
  df_claims = df_claims[df_claims[column].apply(is_likely_text)]
len(df_claims)
# Out:
# 52640

# %%
str_columns_good_to_have = ['claimant', 'claimDate', 'publisher_name']

# %%
for column in str_columns_good_to_have:
  # Instead of filtering, display rows that don't meet the criteria
  print(f"Rows in '{column}' that are not likely text:")
  print(df_claims[~df_claims[column].apply(is_likely_text) & df_claims[column].notna()])
  print("-" * 50) # Separator for better readability
# Out:
# Rows in 'claimant' that are not likely text:
# Empty DataFrame
# Columns: [Unnamed: 0, text, claimant, claimDate, publisher_name, publisher_site, url, title, reviewDate, textualRating, languageCode, publisher_from_list, explanation, simplified_textualRating, text_en]
# Index: []
# --------------------------------------------------
# Rows in 'claimDate' that are not likely text:
# Empty DataFrame
# Columns: [Unnamed: 0, text, claimant, claimDate, publisher_name, publisher_site, url, title, reviewDate, textualRating, languageCode, publisher_from_list, explanation, simplified_textualRating, text_en]
# Index: []
# --------------------------------------------------
# Rows in 'publisher_name' that are not likely text:
# Empty DataFrame
# Columns: [Unnamed: 0, text, claimant, claimDate, publisher_name, publisher_site, url, title, reviewDate, textualRating, languageCode, publisher_from_list, explanation, simplified_textualRating, text_en]
# Index: []
# --------------------------------------------------

# %%
for column in str_columns_good_to_have:
  df_claims = df_claims[df_claims[column].apply(is_likely_text) | df_claims[column].isna()]
len(df_claims)
# Out:
# 52640

# %%
date_columns = ['claimDate', 'reviewDate']

# %%
# Check for invalid dates in 'claimDate' and 'reviewDate' columns
for col in date_columns:
    invalid_dates = df_claims[
        ~pd.to_datetime(df_claims[col], errors='coerce').notna() & df_claims[col].notna()
    ]
    print(f"Rows with invalid or non-date values in '{col}':")
    print(invalid_dates[[col]])  # Display only the problematic column
    print("-" * 50)
# Out:
# Rows with invalid or non-date values in 'claimDate':
# Empty DataFrame
# Columns: [claimDate]
# Index: []
# --------------------------------------------------
# Rows with invalid or non-date values in 'reviewDate':
# Empty DataFrame
# Columns: [reviewDate]
# Index: []
# --------------------------------------------------

# %%
# Remove rows with invalid dates in 'claimDate' and 'reviewDate' columns
for col in date_columns:
    df_claims = df_claims[
        pd.to_datetime(df_claims[col], errors='coerce').notna() | df_claims[col].isna()]

# %% [markdown]
# ### Duplicate Removal

# %%
duplicate_counts = df_claims['text'].value_counts()
duplicate_texts = duplicate_counts[duplicate_counts > 1]
len(duplicate_texts)
# Out:
# 285

# %%
duplicate_text_counts = df_claims.groupby('text')['publisher_site'].nunique()
duplicate_texts_with_same_publisher = duplicate_text_counts[duplicate_text_counts > 1]

# Sort the DataFrame by 'text' to group duplicates together
df_claims_sorted = df_claims.sort_values('text')

# Filter the DataFrame to include only rows with duplicated text and same publisher
duplicated_df = df_claims_sorted[df_claims_sorted['text'].isin(duplicate_texts_with_same_publisher.index)]

# Print the duplicated rows
len(duplicated_df)
# Out:
# 112

# %%
# Convert 'reviewDate' to datetime
df_claims['reviewDate'] = pd.to_datetime(df_claims['reviewDate'])

# Remove duplicates, keeping the row with the latest 'reviewDate'
df_claims = (
    df_claims.sort_values(by="reviewDate", ascending=False)
    .drop_duplicates(subset=["text", "publisher_site"], keep="first")
)
len(df_claims)
# Out:
# 52362

# %% [markdown]
# ### Dataset Overview

# %%
df_claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52362 entries, 34539 to 50466
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                52362 non-null  int64
#  1   text                      52362 non-null  object
#  2   claimant                  52362 non-null  object
#  3   claimDate                 47115 non-null  object
#  4   publisher_name            52362 non-null  object
#  5   publisher_site            52362 non-null  object
#  6   url                       52362 non-null  object
#  7   title                     52362 non-null  object
#  8   reviewDate                45777 non-null  datetime64[ns, UTC]
#  9   textualRating             52362 non-null  object
#  10  languageCode              52362 non-null  object
#  11  publisher_from_list       52362 non-null  object
#  12  explanation               45501 non-null  object
#  13  simplified_textualRating  47484 non-null  object
#  14  text_en                   52362 non-null  object
# dtypes: datetime64[ns, UTC](1), int64(1), object(13)
# memory usage: 6.4+ MB

# %%
len(df_claims['publisher_site'].unique())
# Out:
# 27

# %%
len(df_claims)
# Out:
# 52362

# %%
len(df_claims['textualRating'].unique())
# Out:
# 8549

# %%
df_claims['textualRating'].value_counts()
# Out:
# textualRating
# False                                                                                                     22919
# Misleading                                                                                                 2711
# FALSE                                                                                                      2533
# Fake                                                                                                       1200
# True                                                                                                       1064
#                                                                                                           ...
# This is not true. Transcripts of the speech do not show any mention of Mr Schwab.                             1
# This is false. The man in the picture has a different name and died shortly before the post appeared.         1
# This is incorrect. The man who died has been named as Leonard Farruku, an Albanian national.                  1
# False. The claim is one of many fake news items shared among a suite of supposedly genuine news pages.        1
# This is not true. The British Mandate over Palestine used the Union Jack at this time.                        1
# Name: count, Length: 8549, dtype: int64

# %%
df_claims['languageCode'].value_counts()
# Out:
# languageCode
# en    49116
# ru     2442
# uk      804
# Name: count, dtype: int64

# %%
df_claims.describe()
# Out:
#          Unnamed: 0
# count  52362.000000
# mean   26393.620163
# std    15175.057590
# min        0.000000
# 25%    13280.250000
# 50%    26416.500000
# 75%    39536.750000
# max    52639.000000

# %%
df_claims['publisher_site'].value_counts()
# Out:
# publisher_site
# factcheck.afp.com             5384
# snopes.com                    4416
# leadstories.com               3494
# politifact.com                3425
# usatoday.com                  3243
# factly.in                     2916
# thequint.com                  2790
# fullfact.org                  2430
# newsmeter.in                  2162
# boomlive.in                   2157
# logicallyfacts.com            1936
# provereno.media               1880
# en.youturn.in                 1813
# newschecker.in                1784
# indiatoday.in                 1598
# verafiles.org                 1294
# apnews.com                    1249
# rappler.com                   1204
# aap.com.au                    1139
# checkyourfact.com             1128
# factcheck.org                  959
# stopfake.org                   910
# africacheck.org                773
# vishvasnews.com                752
# srilanka.factcrescendo.com     525
# science.feedback.org           513
# voxukraine.org                 488
# Name: count, dtype: int64

# %%
df_claims[df_claims['languageCode'] == 'uk']['text']
# Out:
# 43115    ФЕЙК: Українська поліція допитує вірян, які св...
# 43114    НЕПРАВДА: Україну «накриває» новий метапневмов...
# 43113    ФЕЙК: В Україні з січня вводять погодинні граф...
# 43120    МАНІПУЛЯЦІЯ: США таємно озброювали Україну з в...
# 43119    НЕПРАВДА: Експорт електроенергії в Молдову спр...
#                                ...
# 37892    Документи про створення тероборони у Волновасі...
# 37884    Відеозапис візиту Зеленського до поранених вій...
# 37783    Росія не використовує курсантів та солдатів ст...
# 37888    Українські націоналісти взяли у полон 6000 іно...
# 37865    ЗСУ використовують фосфорні бомби проти російс...
# Name: text, Length: 804, dtype: object

# %% [markdown]
# ### Create Index Column

# %% [markdown]
# ### Export To CSV - Disabled!

# %%
# df_claims.to_csv('claims_en_ru_ua_last_3_years_filtered1234.csv', index=True)
# files.download('claims_en_ru_ua_last_3_years_filtered1234.csv')

# %% [markdown]
# ### Convertion To Strings And Tackling NAs

# %%
# Rows with NaN in any column
df_claims_with_na = df_claims[df_claims.isna().any(axis=1)]

# Rows with no NaN in any column
df_claims_without_na = df_claims[~df_claims.isna().any(axis=1)]

# %%
df_claims_without_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32790 entries, 31264 to 30919
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                32790 non-null  int64
#  1   text                      32790 non-null  object
#  2   claimant                  32790 non-null  object
#  3   claimDate                 32790 non-null  object
#  4   publisher_name            32790 non-null  object
#  5   publisher_site            32790 non-null  object
#  6   url                       32790 non-null  object
#  7   title                     32790 non-null  object
#  8   reviewDate                32790 non-null  datetime64[ns, UTC]
#  9   textualRating             32790 non-null  object
#  10  languageCode              32790 non-null  object
#  11  publisher_from_list       32790 non-null  object
#  12  explanation               32790 non-null  object
#  13  simplified_textualRating  32790 non-null  object
#  14  text_en                   32790 non-null  object
# dtypes: datetime64[ns, UTC](1), int64(1), object(13)
# memory usage: 4.0+ MB

# %%
df_claims = df_claims_without_na

# %%
df_claims[date_columns] = df_claims[date_columns].apply(pd.to_datetime).astype(int) // 10**9

# %%
# Generate UUIDv7 for each row in the DataFrame
df_claims['primary_key'] = [str(uuid.uuid4()) for _ in range(len(df_claims))]

# Optional: Ensure 'primary_key' is set as the index if required
df_claims.set_index('primary_key', inplace=True)

# %%
df_claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32790 entries, 1572578d-1e37-4e9d-a98a-dd8c2b655449 to 067dbe0d-6ca2-43f3-b969-39f224a90120
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                32790 non-null  int64
#  1   text                      32790 non-null  object
#  2   claimant                  32790 non-null  object
#  3   claimDate                 32790 non-null  int64
#  4   publisher_name            32790 non-null  object
#  5   publisher_site            32790 non-null  object
#  6   url                       32790 non-null  object
#  7   title                     32790 non-null  object
#  8   reviewDate                32790 non-null  int64
#  9   textualRating             32790 non-null  object
#  10  languageCode              32790 non-null  object
#  11  publisher_from_list       32790 non-null  object
#  12  explanation               32790 non-null  object
#  13  simplified_textualRating  32790 non-null  object
#  14  text_en                   32790 non-null  object
# dtypes: int64(3), object(12)
# memory usage: 4.0+ MB

# %% [markdown]
# ## Vector Database

# %% [markdown]
# ### Creating Embeddings

# %%
# Load the model
# model = SentenceTransformer('intfloat/multilingual-e5-small')
model_stella_en_400M_v5 = SentenceTransformer('billatsectorflow/stella_en_400M_v5', trust_remote_code=True)

# Another model we tried -
# model = SentenceTransformer('intfloat/multilingual-e5-large')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of the model checkpoint at billatsectorflow/stella_en_400M_v5 were not used when initializing NewModel: ['new.pooler.dense.bias', 'new.pooler.dense.weight']
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# WARNING:sentence_transformers.SentenceTransformer:Default prompt name is set to 's2p_query'. This prompt will be applied to all `encode()` calls, except if `encode()` is called with `prompt` or `prompt_name` parameters.

# %%
# Generate embeddings with progress tracking
def generate_embeddings(df, text_column="text_en", batch_size=64):
    # Add the required prefix ("passage: ") to the text
    texts = [f"passage: {text}" for text in df[text_column]]
    embeddings = []

    # Process texts in batches and show progress bar
    for i in tqdm(range(0, len(texts), batch_size), desc="Generating embeddings"):
        batch = texts[i:i+batch_size]
        batch_embeddings = model_stella_en_400M_v5.encode(batch, normalize_embeddings=True)
        embeddings.extend(batch_embeddings)

    return embeddings

# Apply embeddings to the "text" column
df_claims["embedding"] = list(generate_embeddings(df_claims, text_column="text_en"))
# Out:
# Generating embeddings:   0%|          | 0/513 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py:1113: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Generating embeddings: 100%|██████████| 513/513 [01:52<00:00,  4.57it/s]

# %% [markdown]
# ### Delete Pinecone Index

# %%
pc.delete_index('connecthack-stella-en-400m-v5-dev')

# %% [markdown]
# ### Create Pinecone Index - Disabled

# %%
pc.create_index(name='connecthack-stella-en-400m-v5-dev', dimension=1024, spec=ServerlessSpec(cloud='aws',region='us-east-1'))

# %% [markdown]
# ### Choose Pinecone Index

# %%
index = pc.Index('connecthack-stella-en-400m-v5-dev')

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1024,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %%
df_claims.columns
# Out:
# Index(['Unnamed: 0', 'text', 'claimant', 'claimDate', 'publisher_name',
#        'publisher_site', 'url', 'title', 'reviewDate', 'textualRating',
#        'languageCode', 'publisher_from_list', 'explanation',
#        'simplified_textualRating', 'text_en', 'embedding'],
#       dtype='object')

# %% [markdown]
# ### Load Data To Pinecone

# %%
# Prepare data for Pinecone
def prepare_pinecone_data(df):
    data = []
    for idx, row in df.iterrows():
        metadata = {
            "text": row["text"],
            "claimant": row["claimant"],
            "claimDate": str(row["claimDate"]),  # Convert to string
            "publisher_name": row["publisher_name"],
            "publisher_site": row["publisher_site"],
            "url": row["url"],
            "title": row["title"],
            "reviewDate": str(row["reviewDate"]),  # Convert to string
            "textualRating": row["textualRating"],
            "languageCode": row["languageCode"],
            "text_en": row["text_en"],
            "simplified_textualRating": row["simplified_textualRating"]
        }
        data.append((str(idx), row["embedding"], metadata))
    return data

# Upload data
pinecone_data = prepare_pinecone_data(df_claims)

# Set the batch size
batch_size = 100

# Add progress bar
for i in tqdm(range(0, len(pinecone_data), batch_size), desc="Uploading to Pinecone", unit="batch"):
    batch = pinecone_data[i:i + batch_size]
    index.upsert(vectors=batch)
# Out:
# Uploading to Pinecone: 100%|██████████| 328/328 [02:58<00:00,  1.84batch/s]

# %% [markdown]
# ### Define Query Function

# %%
def compare_search_results(query_text, index_model_pairs):
    """
    Runs the search_similar_claims function over multiple index-model pairs and formats the results for easy comparison.

    Args:
        query_text (str): The input query text to search for.
        index_model_pairs (list of tuples): A list of (index, model, name) triples.

    Returns:
        None. Prints the results for each index-model pair for comparison.
    """
    results_summary = []

    for index, model, name in index_model_pairs:
        print(f"Running search on: {name}")
        print("=" * 80)

        # Capture results
        has_results = False
        query_embedding = model.encode([f"query: {query_text}"], normalize_embeddings=True)
        results = index.query(vector=query_embedding[0].tolist(), top_k=5, include_metadata=True)
        scores = [result["score"] for result in results["matches"]]
        mean_score = np.mean(scores)
        std_score = np.std(scores)
        threshold = mean_score + 0.5 * std_score

        # Collect and print results
        for result in results["matches"]:
            if result["score"] >= threshold:
                metadata = result["metadata"]
                text = metadata.get("text", "N/A")
                publisher_site = metadata.get("publisher_site", "N/A")
                print(f"Score: {result['score']}")
                print(f"Text: {text}")
                print(f"Publisher Site: {publisher_site}")
                print("-" * 50)  # Separator for readability
                results_summary.append({
                    "name": name,
                    "score": result["score"],
                    "text": text,
                    "publisher_site": publisher_site
                })
                has_results = True

        if not has_results:
            print("No sufficiently similar claims found.")
        print("=" * 80)

# Define the indexes, models, and names
index_model_pairs = [
    (pc.Index('connecthack-stella-en-400m-v5-dev'),
     SentenceTransformer('billatsectorflow/stella_en_400M_v5', trust_remote_code=True),
     "stella_en_400M_v5"),
    (pc.Index('connecthack-e5small-dev'),
     SentenceTransformer('intfloat/multilingual-e5-small'),
     "e5small"),
    (pc.Index('connecthack-e5large'),
     SentenceTransformer('intfloat/multilingual-e5-large'),
     "e5large"),
]
# Out:
# Some weights of the model checkpoint at billatsectorflow/stella_en_400M_v5 were not used when initializing NewModel: ['new.pooler.dense.bias', 'new.pooler.dense.weight']
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# WARNING:sentence_transformers.SentenceTransformer:Default prompt name is set to 's2p_query'. This prompt will be applied to all `encode()` calls, except if `encode()` is called with `prompt` or `prompt_name` parameters.

# %%
def compare_search_results_bulk(df_test, test_columns, pc):
    count_of_querries = 0
    # Define the indexes, models, and names
    index_model_pairs = [
        (pc.Index('connecthack-stella-en-400m-v5-dev'),
        SentenceTransformer('billatsectorflow/stella_en_400M_v5', trust_remote_code=True),
        "stella_en_400M_v5"),
        (pc.Index('connecthack-e5small-dev'),
        SentenceTransformer('intfloat/multilingual-e5-small'),
        "e5small"),
        (pc.Index('connecthack-e5large'),
        SentenceTransformer('intfloat/multilingual-e5-large'),
        "e5large"),
    ]

    hit_dict = {}  # Creates an empty dictionary
    hit_dict = {"stella_en_400M_v5": 0, "e5small": 0, "e5large": 0}

    for i in range(30):  # Iterate from 0 to 30 (inclusive)
        for j in range(3):  # Iterate from 1 to 2 (inclusive)
            try:
                count_of_querries =+ 1
                query_text = df_test[test_columns[i]][j]
                print(f"Processing query: {query_text}")  # Optional: Print the query being processed

                """
                Runs the search_similar_claims function over multiple index-model pairs and formats the results for easy comparison.

                Args:
                    query_text (str): The input query text to search for.
                    index_model_pairs (list of tuples): A list of (index, model, name) triples.

                Returns:
                    None. Prints the results for each index-model pair for comparison.
                """
                results_summary = []
                for index, model, name in index_model_pairs:
                    print(f"Running search on: {name}")
                    print("=" * 80)

                    # Capture results
                    has_results = False
                    query_embedding = model.encode([f"query: {query_text}"], normalize_embeddings=True)
                    results = index.query(vector=query_embedding[0].tolist(), top_k=5, include_metadata=True)
                    scores = [result["score"] for result in results["matches"]]
                    mean_score = np.mean(scores)
                    std_score = np.std(scores)
                    threshold = mean_score + 0.5 * std_score

                    # Collect and print results
                    for result in results["matches"]:
                        if result["score"] >= threshold:
                            metadata = result["metadata"]
                            text = metadata.get("text", "N/A")
                            publisher_site = metadata.get("publisher_site", "N/A")
                            print(f"Score: {result['score']}")
                            print(f"Text: {text}")
                            print(f"Publisher Site: {publisher_site}")
                            print("-" * 50)  # Separator for readability
                            results_summary.append({
                                "name": name,
                                "score": result["score"],
                                "text": text,
                                "publisher_site": publisher_site
                            })
                            has_results = True
                            if text == test_columns[i]:
                                hit_dict[name] = hit_dict.get(name,0) + 1
                            print(hit_dict)
                            print(count_of_querries)


                    if not has_results:
                        print("No sufficiently similar claims found.")
                    print("=" * 80)
            except KeyError:
                print(f"Skipping index {i}, element {j} due to KeyError")  # Handle cases where the index or element might not exist
    return hit_dict

# %%
compare_search_results_bulk(df_test_tr, test_columns, pc)
# Out:
# Some weights of the model checkpoint at billatsectorflow/stella_en_400M_v5 were not used when initializing NewModel: ['new.pooler.dense.bias', 'new.pooler.dense.weight']
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# WARNING:sentence_transformers.SentenceTransformer:Default prompt name is set to 's2p_query'. This prompt will be applied to all `encode()` calls, except if `encode()` is called with `prompt` or `prompt_name` parameters.
# Processing query: Did Barack Obama refer to his wife as "Michael" during a speech?
# Running search on: stella_en_400M_v5
# ================================================================================
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py:1113: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Score: 0.931701481
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 0, 'e5small': 0, 'e5large': 0}
# 1
# Score: 0.883806646
# Text: Barack Obama called his wife Michael in a speech
# Publisher Site: leadstories.com
# --------------------------------------------------
# {'stella_en_400M_v5': 1, 'e5small': 0, 'e5large': 0}
# 1
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.920745194
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 1, 'e5small': 0, 'e5large': 0}
# 1
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.895228267
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 1, 'e5small': 0, 'e5large': 0}
# 1
# Score: 0.894559741
# Text: A video shows former President Barack Obama referring to his wife, Michelle as “Michael.”
# Publisher Site: politifact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 1, 'e5small': 0, 'e5large': 0}
# 1
# ================================================================================
# Processing query: Did Barack Obama ever refer to his wife as Michael in a speech?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.91570729
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 1, 'e5small': 0, 'e5large': 0}
# 1
# Score: 0.867220819
# Text: Barack Obama called his wife Michael in a speech
# Publisher Site: leadstories.com
# --------------------------------------------------
# {'stella_en_400M_v5': 2, 'e5small': 0, 'e5large': 0}
# 1
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.915352702
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 2, 'e5small': 0, 'e5large': 0}
# 1
# Score: 0.904461384
# Text: Barack Obama called his wife Michael in a speech
# Publisher Site: leadstories.com
# --------------------------------------------------
# {'stella_en_400M_v5': 2, 'e5small': 1, 'e5large': 0}
# 1
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.904299378
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 2, 'e5small': 1, 'e5large': 0}
# 1
# Score: 0.894094765
# Text: Barack Obama called his wife Michael in a speech
# Publisher Site: leadstories.com
# --------------------------------------------------
# {'stella_en_400M_v5': 2, 'e5small': 1, 'e5large': 1}
# 1
# ================================================================================
# Processing query: Did Barack Obama refer to his wife as "Michael" during a speech?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.931701481
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 2, 'e5small': 1, 'e5large': 1}
# 1
# Score: 0.883806646
# Text: Barack Obama called his wife Michael in a speech
# Publisher Site: leadstories.com
# --------------------------------------------------
# {'stella_en_400M_v5': 3, 'e5small': 1, 'e5large': 1}
# 1
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.920745194
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 3, 'e5small': 1, 'e5large': 1}
# 1
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.895228267
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 3, 'e5small': 1, 'e5large': 1}
# 1
# Score: 0.894559741
# Text: A video shows former President Barack Obama referring to his wife, Michelle as “Michael.”
# Publisher Site: politifact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 3, 'e5small': 1, 'e5large': 1}
# 1
# ================================================================================
# Skipping index 1, element 0 due to KeyError
# Skipping index 1, element 1 due to KeyError
# Skipping index 1, element 2 due to KeyError
# Processing query: Is it true that images show the Pragyan rover's wheels leaving imprints of the State Emblem of India and ISRO's logo on the Moon's surface?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.916331053
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 4, 'e5small': 1, 'e5large': 1}
# 1
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.940057397
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 4, 'e5small': 2, 'e5large': 1}
# 1
# Score: 0.923881888
# Text: This is an imprint of India’s national emblem and ISRO’s logo left by Pragyan's wheel on the lunar surface.
# Publisher Site: indiatoday.in
# --------------------------------------------------
# {'stella_en_400M_v5': 4, 'e5small': 2, 'e5large': 1}
# 1
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.937600791
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 4, 'e5small': 2, 'e5large': 2}
# 1
# Score: 0.922088504
# Text: This is an imprint of India’s national emblem and ISRO’s logo left by Pragyan's wheel on the lunar surface.
# Publisher Site: indiatoday.in
# --------------------------------------------------
# {'stella_en_400M_v5': 4, 'e5small': 2, 'e5large': 2}
# 1
# ================================================================================
# Processing query: Did the Pragyan rover leave imprints of the State Emblem of India and ISRO's logo on the Moon's surface with its wheels?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.903249145
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 5, 'e5small': 2, 'e5large': 2}
# 1
# Score: 0.861599624
# Text: This is an imprint of India’s national emblem and ISRO’s logo left by Pragyan's wheel on the lunar surface.
# Publisher Site: indiatoday.in
# --------------------------------------------------
# {'stella_en_400M_v5': 5, 'e5small': 2, 'e5large': 2}
# 1
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.941660643
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 5, 'e5small': 3, 'e5large': 2}
# 1
# Score: 0.93585521
# Text: This is an imprint of India’s national emblem and ISRO’s logo left by Pragyan's wheel on the lunar surface.
# Publisher Site: indiatoday.in
# --------------------------------------------------
# {'stella_en_400M_v5': 5, 'e5small': 3, 'e5large': 2}
# 1
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.939813912
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 5, 'e5small': 3, 'e5large': 3}
# 1
# Score: 0.928135157
# Text: This is an imprint of India’s national emblem and ISRO’s logo left by Pragyan's wheel on the lunar surface.
# Publisher Site: indiatoday.in
# --------------------------------------------------
# {'stella_en_400M_v5': 5, 'e5small': 3, 'e5large': 3}
# 1
# ================================================================================
# Processing query: Did the wheels of the Pragyan rover create imprints of the State Emblem of India and ISRO’s logo on the Moon’s surface?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.912706256
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 6, 'e5small': 3, 'e5large': 3}
# 1
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.959981
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 6, 'e5small': 4, 'e5large': 3}
# 1
# Score: 0.930437207
# Text: This is an imprint of India’s national emblem and ISRO’s logo left by Pragyan's wheel on the lunar surface.
# Publisher Site: indiatoday.in
# --------------------------------------------------
# {'stella_en_400M_v5': 6, 'e5small': 4, 'e5large': 3}
# 1
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.944082856
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 6, 'e5small': 4, 'e5large': 4}
# 1
# Score: 0.929049373
# Text: This is an imprint of India’s national emblem and ISRO’s logo left by Pragyan's wheel on the lunar surface.
# Publisher Site: indiatoday.in
# --------------------------------------------------
# {'stella_en_400M_v5': 6, 'e5small': 4, 'e5large': 4}
# 1
# ================================================================================
# Processing query: Is there a video online showing a creature referred to as a 'Mediterranean beef squid'?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.886893511
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 7, 'e5small': 4, 'e5large': 4}
# 1
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.934637964
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 7, 'e5small': 5, 'e5large': 4}
# 1
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.898948908
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 7, 'e5small': 5, 'e5large': 5}
# 1
# ================================================================================
# Processing query: Is it true that a video shows something called a 'Mediterranean beef squid'?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.913928568
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 8, 'e5small': 5, 'e5large': 5}
# 1
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.932091653
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 8, 'e5small': 6, 'e5large': 5}
# 1
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.90409404
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 8, 'e5small': 6, 'e5large': 6}
# 1
# ================================================================================
# Processing query: Does a video truly show a 'Mediterranean beef squid'?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.917839706
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 9, 'e5small': 6, 'e5large': 6}
# 1
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.931892276
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 9, 'e5small': 7, 'e5large': 6}
# 1
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.899601877
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 9, 'e5small': 7, 'e5large': 7}
# 1
# ================================================================================
# Processing query: Is this a photo of the Grand Ethiopian Renaissance Dam?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.90997529
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 10, 'e5small': 7, 'e5large': 7}
# 1
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.935151398
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 10, 'e5small': 8, 'e5large': 7}
# 1
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.902858436
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 10, 'e5small': 8, 'e5large': 8}
# 1
# ================================================================================
# Processing query: Is this a genuine photo of the Grand Ethiopian Renaissance Dam?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.8608585
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 11, 'e5small': 8, 'e5large': 8}
# 1
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.924066663
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 11, 'e5small': 9, 'e5large': 8}
# 1
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.897443175
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 11, 'e5small': 9, 'e5large': 9}
# 1
# ================================================================================
# Processing query: Is this a genuine photo of the Grand Ethiopian Renaissance Dam?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.8608585
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 12, 'e5small': 9, 'e5large': 9}
# 1
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.924066663
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 12, 'e5small': 10, 'e5large': 9}
# 1
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.897443175
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 12, 'e5small': 10, 'e5large': 10}
# 1
# ================================================================================
# Processing query: Is there a video that shows the preparation of artificial cabbages in China?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.934655964
# Text: Video shows preparation of artificial cabbages in China
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 13, 'e5small': 10, 'e5large': 10}
# 1
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.937701285
# Text: Video shows preparation of artificial cabbages in China
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 13, 'e5small': 11, 'e5large': 10}
# 1
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.922528207
# Text: Video shows preparation of artificial cabbages in China
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 13, 'e5small': 11, 'e5large': 11}
# 1
# ================================================================================
# Processing query: Does a video exist that shows artificial cabbages being made in China?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.901295304
# Text: Video shows preparation of artificial cabbages in China
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 14, 'e5small': 11, 'e5large': 11}
# 1
# Score: 0.829061687
# Text: Video shows fake cabbages being made
# Publisher Site: verafiles.org
# --------------------------------------------------
# {'stella_en_400M_v5': 14, 'e5small': 11, 'e5large': 11}
# 1
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.932337344
# Text: Video shows preparation of artificial cabbages in China
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 14, 'e5small': 12, 'e5large': 11}
# 1
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.916063905
# Text: Video shows preparation of artificial cabbages in China
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 14, 'e5small': 12, 'e5large': 12}
# 1
# ================================================================================
# Processing query: Is there a video showing the preparation of artificial cabbages in China?
# Running search on: stella_en_400M_v5
# ================================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-73d3fe7fec17> in <cell line: 0>()
# ----> 1 compare_search_results_bulk(df_test_tr, test_columns, pc)
#
# <ipython-input-35-1f3fdce69565> in compare_search_results_bulk(df_test, test_columns, pc)
#      42                     has_results = False
#      43                     query_embedding = model.encode([f"query: {query_text}"], normalize_embeddings=True)
# ---> 44                     results = index.query(vector=query_embedding[0].tolist(), top_k=5, include_metadata=True)
#      45                     scores = [result["score"] for result in results["matches"]]
#      46                     mean_score = np.mean(scores)
#
# /usr/local/lib/python3.11/dist-packages/pinecone/utils/error_handling.py in inner_func(*args, **kwargs)
#       9     def inner_func(*args, **kwargs):
#      10         try:
# ---> 11             return func(*args, **kwargs)
#      12         except MaxRetryError as e:
#      13             if isinstance(e.reason, ProtocolError):
#
# /usr/local/lib/python3.11/dist-packages/pinecone/data/index.py in query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     439         """
#     440
# --> 441         response = self._query(
#     442             *args,
#     443             top_k=top_k,
#
# /usr/local/lib/python3.11/dist-packages/pinecone/data/index.py in _query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     497         )
#     498
# --> 499         response = self._vector_api.query(
#     500             QueryRequest(
#     501                 **args_dict,
#
# /usr/local/lib/python3.11/dist-packages/pinecone/core/openapi/shared/api_client.py in __call__(self, *args, **kwargs)
#     819
#     820         """
# --> 821         return self.callable(self, *args, **kwargs)
#     822
#     823     def call_with_http_info(self, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/pinecone/core/openapi/data/api/data_plane_api.py in __query(self, query_request, **kwargs)
#     637             kwargs["_host_index"] = kwargs.get("_host_index")
#     638             kwargs["query_request"] = query_request
# --> 639             return self.call_with_http_info(**kwargs)
#     640
#     641         self.query = _Endpoint(
#
# /usr/local/lib/python3.11/dist-packages/pinecone/core/openapi/shared/api_client.py in call_with_http_info(self, **kwargs)
#     877             params["header"]["Content-Type"] = header_list
#     878
# --> 879         return self.api_client.call_api(
#     880             self.settings["endpoint_path"],
#     881             self.settings["http_method"],
#
# /usr/local/lib/python3.11/dist-packages/pinecone/core/openapi/shared/api_client.py in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     429
#     430         if not async_req:
# --> 431             return self.__call_api(
#     432                 resource_path,
#     433                 method,
#
# /usr/local/lib/python3.11/dist-packages/pinecone/core/openapi/shared/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     202         try:
#     203             # perform request and return response
# --> 204             response_data = self.request(
#     205                 method,
#     206                 url,
#
# /usr/local/lib/python3.11/dist-packages/pinecone/core/openapi/shared/api_client.py in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     516             )
#     517         elif method == "POST":
# --> 518             return self.rest_client.POST(
#     519                 url,
#     520                 query_params=query_params,
#
# /usr/local/lib/python3.11/dist-packages/pinecone/core/openapi/shared/rest.py in POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     343         _request_timeout=None,
#     344     ):
# --> 345         return self.request(
#     346             "POST",
#     347             url,
#
# /usr/local/lib/python3.11/dist-packages/pinecone/core/openapi/shared/rest.py in request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     188                     if body is not None:
#     189                         request_body = json.dumps(body)
# --> 190                     r = self.pool_manager.request(
#     191                         method,
#     192                         url,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/_request_methods.py in request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     141             )
#     142         else:
# --> 143             return self.request_encode_body(
#     144                 method, url, fields=fields, headers=headers, **urlopen_kw
#     145             )
#
# /usr/local/lib/python3.11/dist-packages/urllib3/_request_methods.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     276         extra_kw.update(urlopen_kw)
#     277
# --> 278         return self.urlopen(method, url, **extra_kw)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     441             response = conn.urlopen(method, url, **kw)
#     442         else:
# --> 443             response = conn.urlopen(method, u.request_uri, **kw)
#     444
#     445         redirect_location = redirect and response.get_redirect_location()
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in getresponse(self)
#     514
#     515         # Get the response from http.client.HTTPConnection
# --> 516         httplib_response = super().getresponse()
#     517
#     518         try:
#
# /usr/lib/python3.11/http/client.py in getresponse(self)
#    1393         try:
#    1394             try:
# -> 1395                 response.begin()
#    1396             except ConnectionError:
#    1397                 self.close()
#
# /usr/lib/python3.11/http/client.py in begin(self)
#     323         # read until we get a non-100 response
#     324         while True:
# --> 325             version, status, reason = self._read_status()
#     326             if status != CONTINUE:
#     327                 break
#
# /usr/lib/python3.11/http/client.py in _read_status(self)
#     284
#     285     def _read_status(self):
# --> 286         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287         if len(line) > _MAXLINE:
#     288             raise LineTooLong("status line")
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# /usr/lib/python3.11/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1312                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313                   self.__class__)
# -> 1314             return self.read(nbytes, buffer)
#    1315         else:
#    1316             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1164         try:
#    1165             if buffer is not None:
# -> 1166                 return self._sslobj.read(len, buffer)
#    1167             else:
#    1168                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Testing

# %%
# list of synthetic_rephrasals to estimate the quality of the semantic search

# %%
json_translated = {
    "Barack Obama called his wife Michael in a speech": [
        "Did Barack Obama refer to his wife as \"Michael\" during a speech?",
        "Did Barack Obama ever refer to his wife as Michael in a speech?",
        "Did Barack Obama refer to his wife as \"Michael\" during a speech?"
    ],
    "Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo": [
        "Is it true that images show the Pragyan rover's wheels leaving imprints of the State Emblem of India and ISRO's logo on the Moon's surface?",
        "Did the Pragyan rover leave imprints of the State Emblem of India and ISRO's logo on the Moon's surface with its wheels?",
        "Did the wheels of the Pragyan rover create imprints of the State Emblem of India and ISRO’s logo on the Moon’s surface?"
    ],
    "Video shows 'Mediterranean beef squid'": [
        "Is there a video online showing a creature referred to as a 'Mediterranean beef squid'?",
        "Is it true that a video shows something called a 'Mediterranean beef squid'?",
        "Does a video truly show a 'Mediterranean beef squid'?"
    ],
    "Photo of Grand Ethiopian Renaissance Dam": [
        "Is this a photo of the Grand Ethiopian Renaissance Dam?",
        "Is this a genuine photo of the Grand Ethiopian Renaissance Dam?",
        "Is this a genuine photo of the Grand Ethiopian Renaissance Dam?"
    ],
    "Video shows preparation of artificial cabbages in China": [
        "Is there a video that shows the preparation of artificial cabbages in China?",
        "Does a video exist that shows artificial cabbages being made in China?",
        "Is there a video showing the preparation of artificial cabbages in China?"
    ],
    "Livestream showing protests in Kenya on July 19, 2023": [
        "Was there a livestream of the protests in Kenya on July 19, 2023?",
        "Was there a livestream of protests happening in Kenya on July 19, 2023?",
        "Is there a livestream available that covers the protests in Kenya on July 19, 2023?"
    ],
    "Photograph authentically shows a line outside First Republic Bank on the morning of April 28, 2023.": [
        "Is the photograph of a line outside First Republic Bank from the morning of April 28, 2023, authentic?",
        "Is the photograph showing a line outside First Republic Bank on the morning of April 28, 2023 authentic?",
        "Is the photograph that allegedly shows a line outside First Republic Bank on the morning of April 28, 2023, authentic?"
    ],
    "Photo of a little girl with blood on her face is from the Russian invasion of Ukraine in February 2022.": [
        "Is the photo of a little girl with blood on her face from the Russian invasion of Ukraine in February 2022?",
        "Is the widely shared photo of a little girl with blood on her face actually from the Russian invasion of Ukraine in February 2022?",
        "Is the photo of a little girl with blood on her face actually from the Russian invasion of Ukraine in February 2022?"
    ],
    "France sent troops to fight in the Russia-Ukraine war.": [
        "Did France deploy troops to participate in the Russia-Ukraine war?",
        "Did France send troops to fight in the Russia-Ukraine war?",
        "Did France send troops to fight in the Russia-Ukraine war?"
    ],
    "Vice President Kamala Harris was using the help of a teleprompter during a Univision town hall appearance.": [
        "Did Vice President Kamala Harris use a teleprompter during her Univision town hall appearance?",
        "Did Vice President Kamala Harris use a teleprompter during her appearance at a Univision town hall?",
        "Was Vice President Kamala Harris using a teleprompter during her Univision town hall appearance?"
    ],
    "Applying ginger oil on belly button would burn fat ten times faster and eventually help in weight loss": [
        "Does applying ginger oil to the belly button significantly accelerate fat burning and aid in weight loss?",
        "Is it true that applying ginger oil on the belly button can burn fat ten times faster and aid in weight loss?",
        "Is it true that applying ginger oil to the belly button can burn fat ten times faster and aid in weight loss?"
    ],
    "United States President-elect Donald Trump has visited Vice President Sara Duterte to forge an alliance with her family": [
        "Did United States President-elect Donald Trump visit Vice President Sara Duterte to forge an alliance with her family?",
        "Did President-elect Donald Trump visit Vice President Sara Duterte to establish an alliance with her family?",
        "Did United States President-elect Donald Trump visit Vice President Sara Duterte to form an alliance with her family?"
    ],
    "Social media post claiming that this is the photo of the recent Southport attacker.": [
        "Is this photo really of the recent Southport attacker, as claimed on social media?",
        "Is this photo actually of the recent Southport attacker, as claimed on social media?",
        "Is this photo really of the recent Southport attacker, as claimed on social media?"
    ],
    "The meeting between Bongbong Marcos and the Australian prime minister in September 2023 had something to do with retrieving the Marcos family’s gold being kept in Australia.": [
        "Did the meeting between Bongbong Marcos and the Australian prime minister in September 2023 involve discussions about retrieving the Marcos family's gold stored in Australia?",
        "Did the meeting between Bongbong Marcos and the Australian prime minister in September 2023 involve discussions about retrieving the Marcos family’s gold from Australia?",
        "Did the meeting between Bongbong Marcos and the Australian prime minister in September 2023 involve discussions about retrieving the Marcos family’s gold supposedly kept in Australia?"
    ],
    "Photo shows crowd at Trump rally in New York City": [
        "Is the photo actually of a crowd at a Trump rally in New York City?",
        "Is the photo real that supposedly shows a crowd at a Trump rally in New York City?",
        "Is the photo really from a Trump rally in New York City?"
    ],
    "An image shows an eBay listing for a \"used\" Russian tank that was recently seized by Ukrainians.": [
        "Is it true that an image on eBay is showing a listing for a \"used\" Russian tank that was recently seized by Ukrainians?",
        "Is there a real eBay listing showing a \"used\" Russian tank that was recently seized by Ukrainians?",
        "Is there an actual eBay listing showing a \"used\" Russian tank that was seized by Ukrainians?"
    ]
}

# %%
# Create the pandas DataFrame
df_test_tr = pd.DataFrame.from_dict(json_translated)

# %%
df_test_tr
# Out:
#     Barack Obama called his wife Michael in a speech  \
# 0  Did Barack Obama refer to his wife as "Michael...
# 1  Did Barack Obama ever refer to his wife as Mic...
# 2  Did Barack Obama refer to his wife as "Michael...
#
#   Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo  \
# 0  Is it true that images show the Pragyan rover'...
# 1  Did the Pragyan rover leave imprints of the St...
# 2  Did the wheels of the Pragyan rover create imp...
#
#               Video shows 'Mediterranean beef squid'  \
# 0  Is there a video online showing a creature ref...
# 1  Is it true that a video shows something called...
# 2  Does a video truly show a 'Mediterranean beef ...
#
#             Photo of Grand Ethiopian Renaissance Dam  \
# 0  Is this a photo of the Grand Ethiopian Renaiss...
# 1  Is this a genuine photo of the Grand Ethiopian...
# 2  Is this a genuine photo of the Grand Ethiopian...
#
#   Video shows preparation of artificial cabbages in China  \
# 0  Is there a video that shows the preparation of...
# 1  Does a video exist that shows artificial cabba...
# 2  Is there a video showing the preparation of ar...
#
#   Livestream showing protests in Kenya on July 19, 2023  \
# 0  Was there a livestream of the protests in Keny...
# 1  Was there a livestream of protests happening i...
# 2  Is there a livestream available that covers th...
#
#   Photograph authentically shows a line outside First Republic Bank on the morning of April 28, 2023.  \
# 0  Is the photograph of a line outside First Repu...
# 1  Is the photograph showing a line outside First...
# 2  Is the photograph that allegedly shows a line ...
#
#   Photo of a little girl with blood on her face is from the Russian invasion of Ukraine in February 2022.  \
# 0  Is the photo of a little girl with blood on he...
# 1  Is the widely shared photo of a little girl wi...
# 2  Is the photo of a little girl with blood on he...
#
#   France sent troops to fight in the Russia-Ukraine war.  \
# 0  Did France deploy troops to participate in the...
# 1  Did France send troops to fight in the Russia-...
# 2  Did France send troops to fight in the Russia-...
#
#   Vice President Kamala Harris was using the help of a teleprompter during a Univision town hall appearance.  \
# 0  Did Vice President Kamala Harris use a telepro...
# 1  Did Vice President Kamala Harris use a telepro...
# 2  Was Vice President Kamala Harris using a telep...
#
#   Applying ginger oil on belly button would burn fat ten times faster and eventually help in weight loss  \
# 0  Does applying ginger oil to the belly button s...
# 1  Is it true that applying ginger oil on the bel...
# 2  Is it true that applying ginger oil to the bel...
#
#   United States President-elect Donald Trump has visited Vice President Sara Duterte to forge an alliance with her family  \
# 0  Did United States President-elect Donald Trump...
# 1  Did President-elect Donald Trump visit Vice Pr...
# 2  Did United States President-elect Donald Trump...
#
#   Social media post claiming that this is the photo of the recent Southport attacker.  \
# 0  Is this photo really of the recent Southport a...
# 1  Is this photo actually of the recent Southport...
# 2  Is this photo really of the recent Southport a...
#
#   The meeting between Bongbong Marcos and the Australian prime minister in September 2023 had something to do with retrieving the Marcos family’s gold being kept in Australia.  \
# 0  Did the meeting between Bongbong Marcos and th...
# 1  Did the meeting between Bongbong Marcos and th...
# 2  Did the meeting between Bongbong Marcos and th...
#
#    Photo shows crowd at Trump rally in New York City  \
# 0  Is the photo actually of a crowd at a Trump ra...
# 1  Is the photo real that supposedly shows a crow...
# 2  Is the photo really from a Trump rally in New ...
#
#   An image shows an eBay listing for a "used" Russian tank that was recently seized by Ukrainians.
# 0  Is it true that an image on eBay is showing a ...
# 1  Is there a real eBay listing showing a "used" ...
# 2  Is there an actual eBay listing showing a "use...

# %%
test_columns = df_test_tr.columns

# %%
### testing function

# %%
def compare_search_results_bulk(df_test, test_columns, pc):
    count_of_querries = 0
    # Define the indexes, models, and names
    index_model_pairs = [
        (pc.Index('connecthack-stella-en-400m-v5-dev'),
        SentenceTransformer('billatsectorflow/stella_en_400M_v5', trust_remote_code=True),
        "stella_en_400M_v5"),
        (pc.Index('connecthack-e5small-dev'),
        SentenceTransformer('intfloat/multilingual-e5-small'),
        "e5small"),
        (pc.Index('connecthack-e5large'),
        SentenceTransformer('intfloat/multilingual-e5-large'),
        "e5large"),
    ]

    hit_dict = {}  # Creates an empty dictionary
    hit_dict = {"stella_en_400M_v5": 0, "e5small": 0, "e5large": 0}

    for i in range(16):  # Iterate from 0 to 30 (inclusive)
        for j in range(3):  # Iterate from 1 to 2 (inclusive)
            try:
                count_of_querries += 1
                query_text = df_test[test_columns[i]][j]
                print(f"Processing query: {query_text}")  # Optional: Print the query being processed

                """
                Runs the search_similar_claims function over multiple index-model pairs and formats the results for easy comparison.

                Args:
                    query_text (str): The input query text to search for.
                    index_model_pairs (list of tuples): A list of (index, model, name) triples.

                Returns:
                    None. Prints the results for each index-model pair for comparison.
                """
                results_summary = []
                for index, model, name in index_model_pairs:
                    print(f"Running search on: {name}")
                    print("=" * 80)

                    # Capture results
                    has_results = False
                    query_embedding = model.encode([f"query: {query_text}"], normalize_embeddings=True)
                    results = index.query(vector=query_embedding[0].tolist(), top_k=5, include_metadata=True)
                    scores = [result["score"] for result in results["matches"]]
                    mean_score = np.mean(scores)
                    std_score = np.std(scores)
                    threshold = mean_score + 0.5 * std_score

                    # Collect and print results
                    for result in results["matches"]:
                        if result["score"] >= threshold:
                            metadata = result["metadata"]
                            text = metadata.get("text", "N/A")
                            publisher_site = metadata.get("publisher_site", "N/A")
                            print(f"Score: {result['score']}")
                            print(f"Text: {text}")
                            print(f"Publisher Site: {publisher_site}")
                            print("-" * 50)  # Separator for readability
                            results_summary.append({
                                "name": name,
                                "score": result["score"],
                                "text": text,
                                "publisher_site": publisher_site
                            })
                            has_results = True
                            if text == test_columns[i]:
                                hit_dict[name] = hit_dict.get(name,0) + 1
                            print(hit_dict)
                            print(count_of_querries)


                    if not has_results:
                        print("No sufficiently similar claims found.")
                    print("=" * 80)
            except KeyError:
                print(f"Skipping index {i}, element {j} due to KeyError")  # Handle cases where the index or element might not exist
    return hit_dict

# %%
compare_search_results_bulk(df_test_tr, test_columns, pc)
# Out:
# Some weights of the model checkpoint at billatsectorflow/stella_en_400M_v5 were not used when initializing NewModel: ['new.pooler.dense.bias', 'new.pooler.dense.weight']
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# WARNING:sentence_transformers.SentenceTransformer:Default prompt name is set to 's2p_query'. This prompt will be applied to all `encode()` calls, except if `encode()` is called with `prompt` or `prompt_name` parameters.
# Processing query: Did Barack Obama refer to his wife as "Michael" during a speech?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.931701481
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 0, 'e5small': 0, 'e5large': 0}
# 1
# Score: 0.883806646
# Text: Barack Obama called his wife Michael in a speech
# Publisher Site: leadstories.com
# --------------------------------------------------
# {'stella_en_400M_v5': 1, 'e5small': 0, 'e5large': 0}
# 1
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.920745194
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 1, 'e5small': 0, 'e5large': 0}
# 1
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.895228267
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 1, 'e5small': 0, 'e5large': 0}
# 1
# Score: 0.894559741
# Text: A video shows former President Barack Obama referring to his wife, Michelle as “Michael.”
# Publisher Site: politifact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 1, 'e5small': 0, 'e5large': 0}
# 1
# ================================================================================
# Processing query: Did Barack Obama ever refer to his wife as Michael in a speech?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.91570729
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 1, 'e5small': 0, 'e5large': 0}
# 2
# Score: 0.867220819
# Text: Barack Obama called his wife Michael in a speech
# Publisher Site: leadstories.com
# --------------------------------------------------
# {'stella_en_400M_v5': 2, 'e5small': 0, 'e5large': 0}
# 2
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.915352702
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 2, 'e5small': 0, 'e5large': 0}
# 2
# Score: 0.904461384
# Text: Barack Obama called his wife Michael in a speech
# Publisher Site: leadstories.com
# --------------------------------------------------
# {'stella_en_400M_v5': 2, 'e5small': 1, 'e5large': 0}
# 2
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.904299378
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 2, 'e5small': 1, 'e5large': 0}
# 2
# Score: 0.894094765
# Text: Barack Obama called his wife Michael in a speech
# Publisher Site: leadstories.com
# --------------------------------------------------
# {'stella_en_400M_v5': 2, 'e5small': 1, 'e5large': 1}
# 2
# ================================================================================
# Processing query: Did Barack Obama refer to his wife as "Michael" during a speech?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.931701481
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 2, 'e5small': 1, 'e5large': 1}
# 3
# Score: 0.883806646
# Text: Barack Obama called his wife Michael in a speech
# Publisher Site: leadstories.com
# --------------------------------------------------
# {'stella_en_400M_v5': 3, 'e5small': 1, 'e5large': 1}
# 3
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.920745194
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 3, 'e5small': 1, 'e5large': 1}
# 3
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.895228267
# Text: Barack Obama referred to his wife as Michael in a speech
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 3, 'e5small': 1, 'e5large': 1}
# 3
# Score: 0.894559741
# Text: A video shows former President Barack Obama referring to his wife, Michelle as “Michael.”
# Publisher Site: politifact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 3, 'e5small': 1, 'e5large': 1}
# 3
# ================================================================================
# Processing query: Is it true that images show the Pragyan rover's wheels leaving imprints of the State Emblem of India and ISRO's logo on the Moon's surface?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.916331053
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 4, 'e5small': 1, 'e5large': 1}
# 4
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.940057397
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 4, 'e5small': 2, 'e5large': 1}
# 4
# Score: 0.923881888
# Text: This is an imprint of India’s national emblem and ISRO’s logo left by Pragyan's wheel on the lunar surface.
# Publisher Site: indiatoday.in
# --------------------------------------------------
# {'stella_en_400M_v5': 4, 'e5small': 2, 'e5large': 1}
# 4
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.937600791
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 4, 'e5small': 2, 'e5large': 2}
# 4
# Score: 0.922088504
# Text: This is an imprint of India’s national emblem and ISRO’s logo left by Pragyan's wheel on the lunar surface.
# Publisher Site: indiatoday.in
# --------------------------------------------------
# {'stella_en_400M_v5': 4, 'e5small': 2, 'e5large': 2}
# 4
# ================================================================================
# Processing query: Did the Pragyan rover leave imprints of the State Emblem of India and ISRO's logo on the Moon's surface with its wheels?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.903249145
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 5, 'e5small': 2, 'e5large': 2}
# 5
# Score: 0.861599624
# Text: This is an imprint of India’s national emblem and ISRO’s logo left by Pragyan's wheel on the lunar surface.
# Publisher Site: indiatoday.in
# --------------------------------------------------
# {'stella_en_400M_v5': 5, 'e5small': 2, 'e5large': 2}
# 5
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.941660643
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 5, 'e5small': 3, 'e5large': 2}
# 5
# Score: 0.93585521
# Text: This is an imprint of India’s national emblem and ISRO’s logo left by Pragyan's wheel on the lunar surface.
# Publisher Site: indiatoday.in
# --------------------------------------------------
# {'stella_en_400M_v5': 5, 'e5small': 3, 'e5large': 2}
# 5
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.939813912
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 5, 'e5small': 3, 'e5large': 3}
# 5
# Score: 0.928135157
# Text: This is an imprint of India’s national emblem and ISRO’s logo left by Pragyan's wheel on the lunar surface.
# Publisher Site: indiatoday.in
# --------------------------------------------------
# {'stella_en_400M_v5': 5, 'e5small': 3, 'e5large': 3}
# 5
# ================================================================================
# Processing query: Did the wheels of the Pragyan rover create imprints of the State Emblem of India and ISRO’s logo on the Moon’s surface?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.912706256
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 6, 'e5small': 3, 'e5large': 3}
# 6
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.959981
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 6, 'e5small': 4, 'e5large': 3}
# 6
# Score: 0.930437207
# Text: This is an imprint of India’s national emblem and ISRO’s logo left by Pragyan's wheel on the lunar surface.
# Publisher Site: indiatoday.in
# --------------------------------------------------
# {'stella_en_400M_v5': 6, 'e5small': 4, 'e5large': 3}
# 6
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.944082856
# Text: Image depicting imprints on the Moon’s surface created by the wheels of the Pragyan rover, featuring the State Emblem of India and ISRO’s logo
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 6, 'e5small': 4, 'e5large': 4}
# 6
# Score: 0.929049373
# Text: This is an imprint of India’s national emblem and ISRO’s logo left by Pragyan's wheel on the lunar surface.
# Publisher Site: indiatoday.in
# --------------------------------------------------
# {'stella_en_400M_v5': 6, 'e5small': 4, 'e5large': 4}
# 6
# ================================================================================
# Processing query: Is there a video online showing a creature referred to as a 'Mediterranean beef squid'?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.886893511
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 7, 'e5small': 4, 'e5large': 4}
# 7
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.934637964
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 7, 'e5small': 5, 'e5large': 4}
# 7
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.898948908
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 7, 'e5small': 5, 'e5large': 5}
# 7
# ================================================================================
# Processing query: Is it true that a video shows something called a 'Mediterranean beef squid'?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.913928568
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 8, 'e5small': 5, 'e5large': 5}
# 8
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.932091653
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 8, 'e5small': 6, 'e5large': 5}
# 8
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.90409404
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 8, 'e5small': 6, 'e5large': 6}
# 8
# ================================================================================
# Processing query: Does a video truly show a 'Mediterranean beef squid'?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.917839706
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 9, 'e5small': 6, 'e5large': 6}
# 9
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.931892276
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 9, 'e5small': 7, 'e5large': 6}
# 9
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.899601877
# Text: Video shows 'Mediterranean beef squid'
# Publisher Site: usatoday.com
# --------------------------------------------------
# {'stella_en_400M_v5': 9, 'e5small': 7, 'e5large': 7}
# 9
# ================================================================================
# Processing query: Is this a photo of the Grand Ethiopian Renaissance Dam?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.90997529
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 10, 'e5small': 7, 'e5large': 7}
# 10
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.935151398
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 10, 'e5small': 8, 'e5large': 7}
# 10
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.902858436
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 10, 'e5small': 8, 'e5large': 8}
# 10
# ================================================================================
# Processing query: Is this a genuine photo of the Grand Ethiopian Renaissance Dam?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.8608585
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 11, 'e5small': 8, 'e5large': 8}
# 11
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.924066663
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 11, 'e5small': 9, 'e5large': 8}
# 11
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.897443175
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 11, 'e5small': 9, 'e5large': 9}
# 11
# ================================================================================
# Processing query: Is this a genuine photo of the Grand Ethiopian Renaissance Dam?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.8608585
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 12, 'e5small': 9, 'e5large': 9}
# 12
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.924066663
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 12, 'e5small': 10, 'e5large': 9}
# 12
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.897443175
# Text: Photo of Grand Ethiopian Renaissance Dam
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 12, 'e5small': 10, 'e5large': 10}
# 12
# ================================================================================
# Processing query: Is there a video that shows the preparation of artificial cabbages in China?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.934655964
# Text: Video shows preparation of artificial cabbages in China
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 13, 'e5small': 10, 'e5large': 10}
# 13
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.937701285
# Text: Video shows preparation of artificial cabbages in China
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 13, 'e5small': 11, 'e5large': 10}
# 13
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.922528207
# Text: Video shows preparation of artificial cabbages in China
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 13, 'e5small': 11, 'e5large': 11}
# 13
# ================================================================================
# Processing query: Does a video exist that shows artificial cabbages being made in China?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.901295304
# Text: Video shows preparation of artificial cabbages in China
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 14, 'e5small': 11, 'e5large': 11}
# 14
# Score: 0.829061687
# Text: Video shows fake cabbages being made
# Publisher Site: verafiles.org
# --------------------------------------------------
# {'stella_en_400M_v5': 14, 'e5small': 11, 'e5large': 11}
# 14
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.932337344
# Text: Video shows preparation of artificial cabbages in China
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 14, 'e5small': 12, 'e5large': 11}
# 14
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.916063905
# Text: Video shows preparation of artificial cabbages in China
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 14, 'e5small': 12, 'e5large': 12}
# 14
# ================================================================================
# Processing query: Is there a video showing the preparation of artificial cabbages in China?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.934815764
# Text: Video shows preparation of artificial cabbages in China
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 15, 'e5small': 12, 'e5large': 12}
# 15
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.938904166
# Text: Video shows preparation of artificial cabbages in China
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 15, 'e5small': 13, 'e5large': 12}
# 15
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.923384666
# Text: Video shows preparation of artificial cabbages in China
# Publisher Site: factly.in
# --------------------------------------------------
# {'stella_en_400M_v5': 15, 'e5small': 13, 'e5large': 13}
# 15
# ================================================================================
# Processing query: Was there a livestream of the protests in Kenya on July 19, 2023?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.928150535
# Text: Livestream showing protests in Kenya on July 19, 2023
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 16, 'e5small': 13, 'e5large': 13}
# 16
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.920976281
# Text: Livestream showing protests in Kenya on July 19, 2023
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 16, 'e5small': 14, 'e5large': 13}
# 16
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.894154847
# Text: Livestream showing protests in Kenya on July 19, 2023
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 16, 'e5small': 14, 'e5large': 14}
# 16
# ================================================================================
# Processing query: Was there a livestream of protests happening in Kenya on July 19, 2023?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.935768604
# Text: Livestream showing protests in Kenya on July 19, 2023
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 17, 'e5small': 14, 'e5large': 14}
# 17
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.919647694
# Text: Livestream showing protests in Kenya on July 19, 2023
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 17, 'e5small': 15, 'e5large': 14}
# 17
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.897955656
# Text: Livestream showing protests in Kenya on July 19, 2023
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 17, 'e5small': 15, 'e5large': 15}
# 17
# ================================================================================
# Processing query: Is there a livestream available that covers the protests in Kenya on July 19, 2023?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.920814931
# Text: Livestream showing protests in Kenya on July 19, 2023
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 18, 'e5small': 15, 'e5large': 15}
# 18
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.923900723
# Text: Livestream showing protests in Kenya on July 19, 2023
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 18, 'e5small': 16, 'e5large': 15}
# 18
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.926202238
# Text: Livestream showing protests in Kenya on July 19, 2023
# Publisher Site: factcheck.afp.com
# --------------------------------------------------
# {'stella_en_400M_v5': 18, 'e5small': 16, 'e5large': 16}
# 18
# ================================================================================
# Processing query: Is the photograph of a line outside First Republic Bank from the morning of April 28, 2023, authentic?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.929552138
# Text: Photograph authentically shows a line outside First Republic Bank on the morning of April 28, 2023.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 19, 'e5small': 16, 'e5large': 16}
# 19
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.937862754
# Text: Photograph authentically shows a line outside First Republic Bank on the morning of April 28, 2023.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 19, 'e5small': 17, 'e5large': 16}
# 19
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.910098791
# Text: Photograph authentically shows a line outside First Republic Bank on the morning of April 28, 2023.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 19, 'e5small': 17, 'e5large': 17}
# 19
# ================================================================================
# Processing query: Is the photograph showing a line outside First Republic Bank on the morning of April 28, 2023 authentic?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.936917484
# Text: Photograph authentically shows a line outside First Republic Bank on the morning of April 28, 2023.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 20, 'e5small': 17, 'e5large': 17}
# 20
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.940127671
# Text: Photograph authentically shows a line outside First Republic Bank on the morning of April 28, 2023.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 20, 'e5small': 18, 'e5large': 17}
# 20
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.911649
# Text: Photograph authentically shows a line outside First Republic Bank on the morning of April 28, 2023.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 20, 'e5small': 18, 'e5large': 18}
# 20
# ================================================================================
# Processing query: Is the photograph that allegedly shows a line outside First Republic Bank on the morning of April 28, 2023, authentic?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.926263034
# Text: Photograph authentically shows a line outside First Republic Bank on the morning of April 28, 2023.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 21, 'e5small': 18, 'e5large': 18}
# 21
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.930985868
# Text: Photograph authentically shows a line outside First Republic Bank on the morning of April 28, 2023.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 21, 'e5small': 19, 'e5large': 18}
# 21
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.914561629
# Text: Photograph authentically shows a line outside First Republic Bank on the morning of April 28, 2023.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 21, 'e5small': 19, 'e5large': 19}
# 21
# ================================================================================
# Processing query: Is the photo of a little girl with blood on her face from the Russian invasion of Ukraine in February 2022?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.942645907
# Text: Photo of a little girl with blood on her face is from the Russian invasion of Ukraine in February 2022.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 22, 'e5small': 19, 'e5large': 19}
# 22
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.938732088
# Text: Photo of a little girl with blood on her face is from the Russian invasion of Ukraine in February 2022.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 22, 'e5small': 20, 'e5large': 19}
# 22
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.933042467
# Text: Photo of a little girl with blood on her face is from the Russian invasion of Ukraine in February 2022.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 22, 'e5small': 20, 'e5large': 20}
# 22
# ================================================================================
# Processing query: Is the widely shared photo of a little girl with blood on her face actually from the Russian invasion of Ukraine in February 2022?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.918565273
# Text: Photo of a little girl with blood on her face is from the Russian invasion of Ukraine in February 2022.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 23, 'e5small': 20, 'e5large': 20}
# 23
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.932807446
# Text: Photo of a little girl with blood on her face is from the Russian invasion of Ukraine in February 2022.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 23, 'e5small': 21, 'e5large': 20}
# 23
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.928440928
# Text: Photo of a little girl with blood on her face is from the Russian invasion of Ukraine in February 2022.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 23, 'e5small': 21, 'e5large': 21}
# 23
# ================================================================================
# Processing query: Is the photo of a little girl with blood on her face actually from the Russian invasion of Ukraine in February 2022?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.930271506
# Text: Photo of a little girl with blood on her face is from the Russian invasion of Ukraine in February 2022.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 24, 'e5small': 21, 'e5large': 21}
# 24
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.938255429
# Text: Photo of a little girl with blood on her face is from the Russian invasion of Ukraine in February 2022.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 24, 'e5small': 22, 'e5large': 21}
# 24
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.93368566
# Text: Photo of a little girl with blood on her face is from the Russian invasion of Ukraine in February 2022.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 24, 'e5small': 22, 'e5large': 22}
# 24
# ================================================================================
# Processing query: Did France deploy troops to participate in the Russia-Ukraine war?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.860740423
# Text: France sent troops to fight in the Russia-Ukraine war.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 25, 'e5small': 22, 'e5large': 22}
# 25
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.890832961
# Text: France sent troops to fight in the Russia-Ukraine war.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 25, 'e5small': 23, 'e5large': 22}
# 25
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.892049432
# Text: France sent troops to fight in the Russia-Ukraine war.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 25, 'e5small': 23, 'e5large': 23}
# 25
# ================================================================================
# Processing query: Did France send troops to fight in the Russia-Ukraine war?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.913272679
# Text: France sent troops to fight in the Russia-Ukraine war.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 26, 'e5small': 23, 'e5large': 23}
# 26
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.911349893
# Text: France sent troops to fight in the Russia-Ukraine war.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 26, 'e5small': 24, 'e5large': 23}
# 26
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.908351779
# Text: France sent troops to fight in the Russia-Ukraine war.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 26, 'e5small': 24, 'e5large': 24}
# 26
# ================================================================================
# Processing query: Did France send troops to fight in the Russia-Ukraine war?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.913272679
# Text: France sent troops to fight in the Russia-Ukraine war.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 27, 'e5small': 24, 'e5large': 24}
# 27
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.911349893
# Text: France sent troops to fight in the Russia-Ukraine war.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 27, 'e5small': 25, 'e5large': 24}
# 27
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.908351779
# Text: France sent troops to fight in the Russia-Ukraine war.
# Publisher Site: apnews.com
# --------------------------------------------------
# {'stella_en_400M_v5': 27, 'e5small': 25, 'e5large': 25}
# 27
# ================================================================================
# Processing query: Did Vice President Kamala Harris use a teleprompter during her Univision town hall appearance?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.926698446
# Text: Kamala Harris used a teleprompter during her town hall appearance on Univision.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 27, 'e5small': 25, 'e5large': 25}
# 28
# Score: 0.9249596
# Text: Vice President Kamala Harris was using the help of a teleprompter during a Univision town hall appearance.
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 28, 'e5small': 25, 'e5large': 25}
# 28
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.928783655
# Text: Vice President Kamala Harris was using the help of a teleprompter during a Univision town hall appearance.
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 28, 'e5small': 26, 'e5large': 25}
# 28
# Score: 0.927764773
# Text: Kamala Harris used a teleprompter during her town hall appearance on Univision.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 28, 'e5small': 26, 'e5large': 25}
# 28
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.921868205
# Text: Vice President Kamala Harris was using the help of a teleprompter during a Univision town hall appearance.
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 28, 'e5small': 26, 'e5large': 26}
# 28
# Score: 0.911062777
# Text: Kamala Harris used a teleprompter during her town hall appearance on Univision.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 28, 'e5small': 26, 'e5large': 26}
# 28
# ================================================================================
# Processing query: Did Vice President Kamala Harris use a teleprompter during her appearance at a Univision town hall?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.927683771
# Text: Kamala Harris used a teleprompter during her town hall appearance on Univision.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 28, 'e5small': 26, 'e5large': 26}
# 29
# Score: 0.926810086
# Text: Vice President Kamala Harris was using the help of a teleprompter during a Univision town hall appearance.
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 29, 'e5small': 26, 'e5large': 26}
# 29
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.927445114
# Text: Vice President Kamala Harris was using the help of a teleprompter during a Univision town hall appearance.
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 29, 'e5small': 27, 'e5large': 26}
# 29
# Score: 0.926977932
# Text: Kamala Harris used a teleprompter during her town hall appearance on Univision.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 29, 'e5small': 27, 'e5large': 26}
# 29
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.922024608
# Text: Vice President Kamala Harris was using the help of a teleprompter during a Univision town hall appearance.
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 29, 'e5small': 27, 'e5large': 27}
# 29
# Score: 0.90888226
# Text: Kamala Harris used a teleprompter during her town hall appearance on Univision.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 29, 'e5small': 27, 'e5large': 27}
# 29
# ================================================================================
# Processing query: Was Vice President Kamala Harris using a teleprompter during her Univision town hall appearance?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.925073087
# Text: Vice President Kamala Harris was using the help of a teleprompter during a Univision town hall appearance.
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 30, 'e5small': 27, 'e5large': 27}
# 30
# Score: 0.923319399
# Text: Kamala Harris used a teleprompter during her town hall appearance on Univision.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 30, 'e5small': 27, 'e5large': 27}
# 30
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.926831126
# Text: Vice President Kamala Harris was using the help of a teleprompter during a Univision town hall appearance.
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 30, 'e5small': 28, 'e5large': 27}
# 30
# Score: 0.925034404
# Text: Kamala Harris used a teleprompter during her town hall appearance on Univision.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 30, 'e5small': 28, 'e5large': 27}
# 30
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.923256695
# ...
# 38
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.92832768
# Text: Social media post claiming that this is the photo of the recent Southport attacker.
# Publisher Site: logicallyfacts.com
# --------------------------------------------------
# {'stella_en_400M_v5': 38, 'e5small': 36, 'e5large': 36}
# 38
# ================================================================================
# Processing query: Is this photo really of the recent Southport attacker, as claimed on social media?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.926259339
# Text: Social media post claiming that this is the photo of the recent Southport attacker.
# Publisher Site: logicallyfacts.com
# --------------------------------------------------
# {'stella_en_400M_v5': 39, 'e5small': 36, 'e5large': 36}
# 39
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.943113625
# Text: Social media post claiming that this is the photo of the recent Southport attacker.
# Publisher Site: logicallyfacts.com
# --------------------------------------------------
# {'stella_en_400M_v5': 39, 'e5small': 37, 'e5large': 36}
# 39
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.926474154
# Text: Social media post claiming that this is the photo of the recent Southport attacker.
# Publisher Site: logicallyfacts.com
# --------------------------------------------------
# {'stella_en_400M_v5': 39, 'e5small': 37, 'e5large': 37}
# 39
# ================================================================================
# Processing query: Did the meeting between Bongbong Marcos and the Australian prime minister in September 2023 involve discussions about retrieving the Marcos family's gold stored in Australia?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.939450324
# Text: The meeting between Bongbong Marcos and the Australian prime minister in September 2023 had something to do with retrieving the Marcos family’s gold being kept in Australia.
# Publisher Site: verafiles.org
# --------------------------------------------------
# {'stella_en_400M_v5': 40, 'e5small': 37, 'e5large': 37}
# 40
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.939897656
# Text: The meeting between Bongbong Marcos and the Australian prime minister in September 2023 had something to do with retrieving the Marcos family’s gold being kept in Australia.
# Publisher Site: verafiles.org
# --------------------------------------------------
# {'stella_en_400M_v5': 40, 'e5small': 38, 'e5large': 37}
# 40
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.908204377
# Text: The meeting between Bongbong Marcos and the Australian prime minister in September 2023 had something to do with retrieving the Marcos family’s gold being kept in Australia.
# Publisher Site: verafiles.org
# --------------------------------------------------
# {'stella_en_400M_v5': 40, 'e5small': 38, 'e5large': 38}
# 40
# ================================================================================
# Processing query: Did the meeting between Bongbong Marcos and the Australian prime minister in September 2023 involve discussions about retrieving the Marcos family’s gold from Australia?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.941807866
# Text: The meeting between Bongbong Marcos and the Australian prime minister in September 2023 had something to do with retrieving the Marcos family’s gold being kept in Australia.
# Publisher Site: verafiles.org
# --------------------------------------------------
# {'stella_en_400M_v5': 41, 'e5small': 38, 'e5large': 38}
# 41
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.948012531
# Text: The meeting between Bongbong Marcos and the Australian prime minister in September 2023 had something to do with retrieving the Marcos family’s gold being kept in Australia.
# Publisher Site: verafiles.org
# --------------------------------------------------
# {'stella_en_400M_v5': 41, 'e5small': 39, 'e5large': 38}
# 41
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.919633627
# Text: The meeting between Bongbong Marcos and the Australian prime minister in September 2023 had something to do with retrieving the Marcos family’s gold being kept in Australia.
# Publisher Site: verafiles.org
# --------------------------------------------------
# {'stella_en_400M_v5': 41, 'e5small': 39, 'e5large': 39}
# 41
# ================================================================================
# Processing query: Did the meeting between Bongbong Marcos and the Australian prime minister in September 2023 involve discussions about retrieving the Marcos family’s gold supposedly kept in Australia?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.943672597
# Text: The meeting between Bongbong Marcos and the Australian prime minister in September 2023 had something to do with retrieving the Marcos family’s gold being kept in Australia.
# Publisher Site: verafiles.org
# --------------------------------------------------
# {'stella_en_400M_v5': 42, 'e5small': 39, 'e5large': 39}
# 42
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.952765465
# Text: The meeting between Bongbong Marcos and the Australian prime minister in September 2023 had something to do with retrieving the Marcos family’s gold being kept in Australia.
# Publisher Site: verafiles.org
# --------------------------------------------------
# {'stella_en_400M_v5': 42, 'e5small': 40, 'e5large': 39}
# 42
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.924357951
# Text: The meeting between Bongbong Marcos and the Australian prime minister in September 2023 had something to do with retrieving the Marcos family’s gold being kept in Australia.
# Publisher Site: verafiles.org
# --------------------------------------------------
# {'stella_en_400M_v5': 42, 'e5small': 40, 'e5large': 40}
# 42
# ================================================================================
# Processing query: Is the photo actually of a crowd at a Trump rally in New York City?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.893702686
# Text: Photo shows crowd at Trump rally in New York City
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 43, 'e5small': 40, 'e5large': 40}
# 43
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.918234885
# Text: Photo shows crowd at Trump rally in New York City
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 43, 'e5small': 41, 'e5large': 40}
# 43
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.910277069
# Text: Photo shows crowd at Trump rally in New York City
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 43, 'e5small': 41, 'e5large': 41}
# 43
# ================================================================================
# Processing query: Is the photo real that supposedly shows a crowd at a Trump rally in New York City?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.874858618
# Text: Photo shows crowd at Trump rally in New York City
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 44, 'e5small': 41, 'e5large': 41}
# 44
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.904200077
# Text: Photo shows crowd at Trump rally in New York City
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 44, 'e5small': 42, 'e5large': 41}
# 44
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.895553648
# Text: Photo shows crowd at Trump rally in New York City
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 44, 'e5small': 42, 'e5large': 42}
# 44
# Score: 0.892606437
# Text: Is photo of Donald Trump's "weak" crowd in Waco real?
# Publisher Site: newsweek.com
# --------------------------------------------------
# {'stella_en_400M_v5': 44, 'e5small': 42, 'e5large': 42}
# 44
# ================================================================================
# Processing query: Is the photo really from a Trump rally in New York City?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.864415526
# Text: Photo shows crowd at Trump rally in New York City
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 45, 'e5small': 42, 'e5large': 42}
# 45
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.899465621
# Text: Photo shows crowd at Trump rally in New York City
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 45, 'e5small': 43, 'e5large': 42}
# 45
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.889571965
# Text: Photo shows crowd at Trump rally in New York City
# Publisher Site: checkyourfact.com
# --------------------------------------------------
# {'stella_en_400M_v5': 45, 'e5small': 43, 'e5large': 43}
# 45
# ================================================================================
# Processing query: Is it true that an image on eBay is showing a listing for a "used" Russian tank that was recently seized by Ukrainians?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.92911166
# Text: An image shows an eBay listing for a "used" Russian tank that was recently seized by Ukrainians.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 46, 'e5small': 43, 'e5large': 43}
# 46
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.948245406
# Text: An image shows an eBay listing for a "used" Russian tank that was recently seized by Ukrainians.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 46, 'e5small': 44, 'e5large': 43}
# 46
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.931438506
# Text: An image shows an eBay listing for a "used" Russian tank that was recently seized by Ukrainians.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 46, 'e5small': 44, 'e5large': 44}
# 46
# ================================================================================
# Processing query: Is there a real eBay listing showing a "used" Russian tank that was recently seized by Ukrainians?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.915283442
# Text: An image shows an eBay listing for a "used" Russian tank that was recently seized by Ukrainians.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 47, 'e5small': 44, 'e5large': 44}
# 47
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.948536754
# Text: An image shows an eBay listing for a "used" Russian tank that was recently seized by Ukrainians.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 47, 'e5small': 45, 'e5large': 44}
# 47
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.924417913
# Text: An image shows an eBay listing for a "used" Russian tank that was recently seized by Ukrainians.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 47, 'e5small': 45, 'e5large': 45}
# 47
# ================================================================================
# Processing query: Is there an actual eBay listing showing a "used" Russian tank that was seized by Ukrainians?
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.91900444
# Text: An image shows an eBay listing for a "used" Russian tank that was recently seized by Ukrainians.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 48, 'e5small': 45, 'e5large': 45}
# 48
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.947174907
# Text: An image shows an eBay listing for a "used" Russian tank that was recently seized by Ukrainians.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 48, 'e5small': 46, 'e5large': 45}
# 48
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.925876737
# Text: An image shows an eBay listing for a "used" Russian tank that was recently seized by Ukrainians.
# Publisher Site: snopes.com
# --------------------------------------------------
# {'stella_en_400M_v5': 48, 'e5small': 46, 'e5large': 46}
# 48
# ================================================================================
# {'stella_en_400M_v5': 48, 'e5small': 46, 'e5large': 46}

# %%
# Query text
query = "Putin denied interference in the 2020 U.S. elections."

# Run the comparison
compare_search_results(query, index_model_pairs)
# Out:
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.715316117
# Text: Video shows Russian President Vladimir Putin speaking English to warn Americans about election interference.
# Publisher Site: apnews.com
# --------------------------------------------------
# Score: 0.699208617
# Text: An announcement by U.S. intelligence officials that there's no foreign interference in U.S. elections through early September 2024 undermines the Department of Justice's indictment of alleged Russian operatives.
# Publisher Site: leadstories.com
# --------------------------------------------------
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.876550376
# Text: An announcement by U.S. intelligence officials that there's no foreign interference in U.S. elections through early September 2024 undermines the Department of Justice's indictment of alleged Russian operatives.
# Publisher Site: leadstories.com
# --------------------------------------------------
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.848732233
# Text: An announcement by U.S. intelligence officials that there's no foreign interference in U.S. elections through early September 2024 undermines the Department of Justice's indictment of alleged Russian operatives.
# Publisher Site: leadstories.com
# --------------------------------------------------
# Score: 0.828535259
# Text: Video shows Russian President Vladimir Putin speaking English to warn Americans about election interference.
# Publisher Site: apnews.com
# --------------------------------------------------
# ================================================================================

# %%
# Query text
query = "Russia is forcibly relocating Ukrainian children to Russian territory."

# Run the comparison
compare_search_results(query, index_model_pairs)
# Out:
# Running search on: stella_en_400M_v5
# ================================================================================
# Score: 0.73999238
# Text: “Dozens Of Ukrainians” Asked Russia For Help In Getting Their Children Back From European Union
# Publisher Site: leadstories.com
# --------------------------------------------------
# ================================================================================
# Running search on: e5small
# ================================================================================
# Score: 0.869551361
# Text: Photograph shows children bidding farewell to Ukrainian forces amid recent war with Russia.
# Publisher Site: thequint.com
# --------------------------------------------------
# Score: 0.865870059
# Text: Дітей в Україні змушують здавати кров для потреб ЗСУ
# Publisher Site: stopfake.org
# --------------------------------------------------
# ================================================================================
# Running search on: e5large
# ================================================================================
# Score: 0.854775846
# Text: Photograph shows children bidding farewell to Ukrainian forces amid recent war with Russia.
# Publisher Site: thequint.com
# --------------------------------------------------
# ================================================================================

# %%
def search_similar_claims_stella(query_text):
    """
    Searches Pinecone for claims similar to the input query text.

    Args:
        query_text (str): The input query text to search for.

    Returns:
        Prints each match with scores and metadata line by line if they meet the threshold,
        or a message indicating no matches found.
    """

    index = pc.Index('connecthack-stella-en-400m-v5-dev')
    model = model_stella_en_400M_v5
    # Generate embedding for the query
    query_embedding = model.encode([f"query: {query_text}"], normalize_embeddings=True)

    # Query Pinecone
    results = index.query(vector=query_embedding[0].tolist(), top_k=5, include_metadata=True)

    # Calculate scores and apply threshold
    scores = [result["score"] for result in results["matches"]]
    mean_score = np.mean(scores)
    std_score = np.std(scores)

    # Threshold logic (minimum of 0.83 or mean + 0.5*std)
    threshold = mean_score + 0.5 * std_score

    has_results = False
    for result in results["matches"]:
        if result["score"] >= threshold:
            print(f"Score: {result['score']}")
            print(f"Metadata: {result['metadata']}")
            print("-" * 50)  # Separator for readability
            has_results = True

    if not has_results:
        print("No sufficiently similar claims found.")

# %%
def search_similar_claims_basic(query_text):
    """
    Searches Pinecone for claims similar to the input query text.

    Args:
        query_text (str): The input query text to search for.

    Returns:
        Prints each match with scores and metadata line by line, or a message indicating no matches found.
    """
    # Generate embedding for the query
    query_embedding = model.encode([f"query: {query_text}"], normalize_embeddings=True)

    # Query Pinecone
    results = index.query(vector=query_embedding[0].tolist(), top_k=5, include_metadata=True)

    # Output all matches
    has_results = False
    for result in results["matches"]:
        print(f"Score: {result['score']}")
        print(f"Metadata: {result['metadata']}")
        print("-" * 50)  # Separator for readability
        has_results = True

    if not has_results:
        print("No matches found.")

# %%
# to improve

query = "Over 10 million Ukrainians have fled the country since 2022"
results = search_similar_claims_stella(query)
print(results)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py:1113: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Score: 0.682023942
# Metadata: {'claimDate': '1692403200', 'claimant': 'Missing', 'languageCode': 'ru', 'publisher_name': 'Проверено.Медиа', 'publisher_site': 'provereno.media', 'reviewDate': '1694304000', 'simplified_textualRating': 'false', 'text': 'с февраля 2022 года в Украине погибло более 10 тысяч польских военных', 'text_en': 'Since February 2022, more than 10,000 Polish military personnel have died in Ukraine.', 'textualRating': 'Фейк', 'title': 'Правда ли, что с февраля 2022 года в Украине погибло более 10 000 польских военных?', 'url': 'https://provereno.media/blog/2023/09/10/pravda-li-chto-s-fevralya-2022-goda-v-ukraine-pogiblo-bolee-10000-polskih-voennyh/'}
# --------------------------------------------------
# Score: 0.670388699
# Metadata: {'claimDate': '1733961600', 'claimant': 'Multiple authors', 'languageCode': 'en', 'publisher_name': 'AFP Fact Check', 'publisher_site': 'factcheck.afp.com', 'reviewDate': '1734467640', 'simplified_textualRating': 'false', 'text': 'ABC News reported one million Ukrainian soldiers have died since 2022', 'text_en': 'ABC News reported one million Ukrainian soldiers have died since 2022', 'textualRating': 'Altered video', 'title': 'ABC News segment altered to inflate Ukrainian soldier deaths', 'url': 'https://factcheck.afp.com/doc.afp.com.36QG8VU'}
# --------------------------------------------------
# None

# %%
# to improve

query = "Trump said that he is going to end the war in ukraine"
results = search_similar_claims_stella(query)
print(results)
# Out:
# Score: 0.698568881
# Metadata: {'claimDate': '1670803200', 'claimant': 'Social media', 'languageCode': 'en', 'publisher_name': 'USA Today', 'publisher_site': 'usatoday.com', 'reviewDate': '1671651012', 'simplified_textualRating': 'false', 'text': 'The war in Ukraine is over', 'text_en': 'The war in Ukraine is over', 'textualRating': 'False', 'title': 'Fact check: War in Ukraine continues, contrary to post', 'url': 'https://www.usatoday.com/story/news/factcheck/2022/12/21/fact-check-russia-ukraine-war-continues-contrary-post/10927862002/'}
# --------------------------------------------------
# Score: 0.697245717
# Metadata: {'claimDate': '1731888000', 'claimant': 'social media', 'languageCode': 'en', 'publisher_name': 'USA Today', 'publisher_site': 'usatoday.com', 'reviewDate': '1732736079', 'simplified_textualRating': 'false', 'text': 'Trump said he would stop Biden from allowing Ukraine to use US missiles', 'text_en': 'Trump said he would stop Biden from allowing Ukraine to use US missiles', 'textualRating': 'False', 'title': 'Trump quote on Biden Ukraine policy started as satire | Fact check', 'url': 'https://www.usatoday.com/story/news/factcheck/2024/11/27/trump-quote-biden-ukraine-satire-fact-check/76567681007/'}
# --------------------------------------------------
# None

# %%
# to improve

query = "Война в Украине закончится в 2025"
results = search_similar_claims(query)
print(results)
# Out:
# Score: 0.879831493
# Metadata: {'claimDate': '2024-12-15 00:00:00+00:00', 'claimant': 'Viral social media post', 'languageCode': 'ru', 'publisher_name': 'StopFake', 'publisher_site': 'stopfake.org', 'reviewDate': '2024-12-17 00:00:00+00:00', 'text': 'Украина планирует сократить в 2025 году расходы на протезирование для военных', 'textualRating': 'В Украине никто не заявлял о планах правительства сократить расходы на протезирование и реабилитацию военных. Государство и впредь будет продолжать обеспечивать бесплатные услуги военным и выделило на это соответствующие средства.', 'title': 'Фейк: Украина планирует сократить в 2025 году расходы на протезирование для военных', 'url': 'https://www.stopfake.org/ru/fejk-ukraina-planiruet-sokratit-v-2025-godu-rashody-na-protezirovanie-dlya-voennyh/'}
# --------------------------------------------------
# Score: 0.878397882
# Metadata: {'claimDate': '2022-02-01 00:00:00+00:00', 'claimant': 'viral social media post', 'languageCode': 'ru', 'publisher_name': 'StopFake', 'publisher_site': 'stopfake.org', 'reviewDate': '2022-02-07 00:00:00+00:00', 'text': 'В 2025 году украинские семьи превратят в предприятия и лишат имущества', 'textualRating': 'Никакого закона о «налогообложении семей» в Украине не существует. Речь идет о проекте закона, который еще даже не рассмотрен комитетами. В документе предлагают создать в Украине новый экономический субъект – домохозяйство, которое сможет осуществлять предпринимательскую деятельность без регистрации ФОП.', 'title': 'Фейк: В 2025 году украинские семьи превратят в предприятия и лишат имущества', 'url': 'https://www.stopfake.org/ru/fejk-v-2025-godu-ukrainskie-semi-prevratyat-v-predpriyatiya-i-lishat-imushhestva/'}
# --------------------------------------------------
# None

# %%
# to improve
query = "Biden criticized Trump for handling the pandemic."
results = search_similar_claims(query)
print(results)
# Out:
# Score: 0.859377861
# Metadata: {'claimDate': '2024-02-20 00:00:00+00:00', 'claimant': 'Donald Trump', 'languageCode': 'en', 'publisher_name': 'FactCheck.org', 'publisher_site': 'factcheck.org', 'reviewDate': '2024-02-21 23:51:52+00:00', 'text': '“Well, they want him [Biden] very badly to be president,” referring to world leaders, including Russian President Vladimir Putin.', 'textualRating': 'Unsupported', 'title': 'Trump Repeats Many Claims in Fox News Town Hall', 'url': 'https://www.factcheck.org/2024/02/trump-repeats-many-claims-in-fox-news-town-hall/'}
# --------------------------------------------------
# None

# %%
query = "Ukranian education wont focus on science anymore"
results = search_similar_claims(query)
print(results)
# Out:
# Score: 0.891417742
# Metadata: {'claimDate': '2025-01-11 00:00:00+00:00', 'claimant': 'Viral social media post', 'languageCode': 'ru', 'publisher_name': 'StopFake', 'publisher_site': 'stopfake.org', 'reviewDate': '2025-01-13 00:00:00+00:00', 'text': 'С 2027 года в украинских школах перестанут изучать естественные науки', 'textualRating': 'Тезис о том, что с 2027 года в украинских школах заберут из программы физику, химию, биологию и географию является манипулятивной, так как искажает суть предложений по образовательной реформе. В действительности эти предметы останутся в школьной программе как обязательные для 10 класса, а вот в 11–12 классах их можно будет изучать как выборочные дисциплины в зависимости от профиля обучения. Реформа направлена на повышение качества образования и предоставляет ученикам больше возможностей для углубленного изучения тех предметов, которые соответствуют их интересам и карьерным планам.', 'title': 'Манипуляция: С 2027 года в украинских школах перестанут изучать естественные науки', 'url': 'https://www.stopfake.org/ru/manipulyatsiya-s-2027-goda-v-ukrainskih-shkolah-perestanut-izuchat-estestvennye-nauki/'}
# --------------------------------------------------
# None

# %%
query = "Байден серьезно болен"
results = search_similar_claims(query)
print(results)
# Out:
# Score: 0.896834552
# Metadata: {'claimDate': '2023-12-21T00:00:00Z', 'claimant': 'Виральные посты в соцсетях и СМИ', 'languageCode': 'ru', 'publisher_name': 'Проверено.Медиа', 'publisher_site': 'provereno.media', 'reviewDate': '2024-01-10T00:00:00Z', 'text': 'Байден обнимается с пустотой', 'textualRating': 'Вырвано из контекста', 'title': 'Правдиво ли видео, на котором Байден пытается обнять невидимого собеседника?', 'url': 'https://provereno.media/blog/2024/01/10/pravdivo-li-video-na-kotorom-bayden-pytaetsya-obnyat-nevidimogo-sobesednika-1/'}
# --------------------------------------------------
# Score: 0.895303786
# Metadata: {'claimDate': '2024-06-06T00:00:00Z', 'claimant': 'Виральные посты в соцсетях', 'languageCode': 'ru', 'publisher_name': 'Проверено.Медиа', 'publisher_site': 'provereno.media', 'reviewDate': '2024-06-07T00:00:00Z', 'text': 'Байден попытался сесть на несуществующий стул', 'textualRating': 'Неправда', 'title': 'Правда ли, что Байден попытался сесть на несуществующий стул?', 'url': 'https://provereno.media/blog/2024/06/07/pravda-li-chto-bajden-popytalsya-sest-na-nesushestvuyushij-stul/'}
# --------------------------------------------------
# None

# %%
query = "Ukraine kill russian innocent civilians"
results = search_similar_claims(query)
print(results)
# Out:
# Score: 0.888457358
# Metadata: {'claimDate': '2022-03-18 06:56:00+00:00', 'claimant': 'Arc.мuнаммаd', 'languageCode': 'ar', 'publisher_name': 'مسبار', 'publisher_site': 'misbar.com', 'reviewDate': '2022-03-18 06:56:00+00:00', 'text': 'A video depicts Ukrainian soldiers killing civilians in Chechnya.', 'textualRating': 'زائف', 'title': 'Movie Clip Falsely Shared as Ukrainian Soldier Killing Chechan Civilians in 1999', 'url': 'https://misbar.com/factcheck/2022/03/18/movie-clip-falsely-shared-as-ukrainian-soldier-killing-chechan-civilians-in-1999'}
# --------------------------------------------------
# Score: 0.888457358
# Metadata: {'claimDate': '2022-03-18 06:56:00+00:00', 'claimant': 'Arc.мuнаммаd', 'languageCode': 'en', 'publisher_name': 'Missing', 'publisher_site': 'misbar.com', 'reviewDate': '2022-03-18 06:56:00+00:00', 'text': 'A video depicts Ukrainian soldiers killing civilians in Chechnya.', 'textualRating': 'Fake', 'title': 'Movie Clip Falsely Shared as Ukrainian Soldier Killing Chechan Civilians in 1999 | Misbar', 'url': 'https://misbar.com/en/factcheck/2022/03/18/movie-clip-falsely-shared-as-ukrainian-soldier-killing-chechan-civilians-in-1999'}
# --------------------------------------------------
# None

# %%
query = "Putin denied interference in the 2020 U.S. elections."
results = search_similar_claims(query)
print(results)
# Out:
# Score: 0.876550257
# Metadata: {'claimDate': '2024-09-11T00:41:00Z', 'claimant': 'zerohedge.com', 'languageCode': 'en', 'publisher_name': 'Lead Stories', 'publisher_site': 'leadstories.com', 'reviewDate': '2024-09-11T00:41:00Z', 'text': "An announcement by U.S. intelligence officials that there's no foreign interference in U.S. elections through early September 2024 undermines the Department of Justice's indictment of alleged Russian operatives.", 'textualRating': 'Not Same Thing', 'title': "Fact Check: US Intelligence Does NOT Undercut DOJ With 'No Foreign Interference' Announcement", 'url': 'https://leadstories.com/hoax-alert/2024/09/fact-check-us-intelligence-does-not-undercut-doj-with-no-foreign-interference-claim.html'}
# --------------------------------------------------
# None

# %%
query = "Stepan Khramov is a very handscome individual"
results = search_similar_claims(query)
print(results)
# Out:
# No sufficiently similar claims found.
# None

# %%
# pc.create_index(name='connecthack-e5small', dimension=384,spec=ServerlessSpec(cloud='aws',region='us-east-1'))

# %%
# index = pc.Index('connecthack-e5small')

# %%
# index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 58109}},
#  'total_vector_count': 58109}

# %%
# # Prepare data for Pinecone
# def prepare_pinecone_data(df):
#     data = []
#     for idx, row in df.iterrows():
#         metadata = {
#             "text": row["text"],
#             "claimant": row["claimant"],
#             "claimDate": str(row["claimDate"]),  # Convert to string
#             "publisher_name": row["publisher_name"],
#             "publisher_site": row["publisher_site"],
#             "url": row["url"],
#             "title": row["title"],
#             "reviewDate": str(row["reviewDate"]),  # Convert to string
#             "textualRating": row["textualRating"],
#             "languageCode": row["languageCode"]
#         }
#         data.append((str(idx), row["embedding"], metadata))
#     return data

# # Upload data
# pinecone_data = prepare_pinecone_data(df_claims)

# # Set the batch size
# batch_size = 100

# # Add progress bar
# for i in tqdm(range(0, len(pinecone_data), batch_size), desc="Uploading to Pinecone", unit="batch"):
#     batch = pinecone_data[i:i + batch_size]
#     index.upsert(vectors=batch)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'embedding'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-fcaeae310625> in <cell line: 0>()
#      19
#      20 # Upload data
# ---> 21 pinecone_data = prepare_pinecone_data(df_claims)
#      22
#      23 # Set the batch size
#
# <ipython-input-57-fcaeae310625> in prepare_pinecone_data(df)
#      15             "languageCode": row["languageCode"]
#      16         }
# ---> 17         data.append((str(idx), row["embedding"], metadata))
#      18     return data
#      19
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# -> 1237         loc = self.index.get_loc(label)
#    1238
#    1239         if is_integer(loc):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'embedding'

# %%
# # Load the model
# model = SentenceTransformer('intfloat/multilingual-e5-small')

# def query_with_threshold(index, model, query_text):

#     # Threshold value
#     threshold = 0.83

#     # Generate embedding for the query
#     query_embedding = model.encode([f"query: {query_text}"], normalize_embeddings=True)

#     # Query Pinecone
#     results = index.query(vector=query_embedding[0].tolist(), top_k=5, include_metadata=True)

#     # Display results with scores above the threshold
#     found = False
#     for result in results["matches"]:
#         if result["score"] >= threshold:
#             print(f"Score: {result['score']}")
#             print(f"Metadata: {result['metadata']}")
#             print("----")
#             found = True
#         else:
#             break

#     if not found:
#         print("No sufficiently similar claims found.")

# %%
# # Query Pinecone
# results = index.query(vector=query_embedding[0].tolist(), top_k=5, include_metadata=True)

# scores = [result["score"] for result in results["matches"]]
# mean_score = np.mean(scores)
# std_score = np.std(scores)

# threshold = mean_score + 0.5 * std_score  # Example adjustment
# for result in results["matches"]:
#     if result["score"] >= threshold:
#         print(f"Score: {result['score']}")
#         print(f"Metadata: {result['metadata']}")
#     else:
#         print("No sufficiently similar claims found.")
#         break

# %%
# query_text = "COVID-19 vaccines are harmful"
# query_with_threshold(index=index, model=model, query_text=query_text)

# %%
# # New claim text
# query_text = "Зеленский употребляет наркотики"
# query_with_threshold(index=index, model=model, query_text=query_text)

# %%
# # New claim text
# query_text = "Байден серьезно болен"
# query_with_threshold(index=index, model=model, query_text=query_text)

# %%
# # New claim text
# query_text = "Lenin didnt believe that the soviet revolution would happen"

# # Generate embedding for the query
# query_embedding = model.encode([f"query: {query_text}"], normalize_embeddings=True)

# # Query Pinecone
# results = index.query(vector=query_embedding[0].tolist(), top_k=5, include_metadata=True)

# # Display results
# for result in results["matches"]:
#     print(f"Score: {result['score']}")
#     print(f"Metadata: {result['metadata']}")
#     print("----")

# %%
# # New claim text
# query_text = "Ukraine kill russian innocent civilians"

# # Generate embedding for the query
# query_embedding = model.encode([f"query: {query_text}"], normalize_embeddings=True)

# # Query Pinecone
# results = index.query(vector=query_embedding[0].tolist(), top_k=5, include_metadata=True)

# # Display results
# for result in results["matches"]:
#     print(f"Score: {result['score']}")
#     print(f"Metadata: {result['metadata']}")
#     print("----")

# %%
# # Load the model
# model = SentenceTransformer('intfloat/multilingual-e5-small')

# # New claim text
# query_text = "Biden criticized Trump for handling the pandemic."

# # Generate embedding for the query
# query_embedding = model.encode([f"query: {query_text}"], normalize_embeddings=True)

# # Query Pinecone
# results = index.query(vector=query_embedding[0].tolist(), top_k=5, include_metadata=True)

# # Display results
# for result in results["matches"]:
#     print(f"Score: {result['score']}")
#     print(f"Metadata: {result['metadata']}")
#     print("----")

# %%
# # New claim text
# query_text = "Putin denied interference in the 2020 U.S. elections."

# # Generate embedding for the query
# query_embedding = model.encode([f"query: {query_text}"], normalize_embeddings=True)

# # Query Pinecone
# results = index.query(vector=query_embedding[0].tolist(), top_k=5, include_metadata=True)

# # Display results
# for result in results["matches"]:
#     print(f"Score: {result['score']}")
#     print(f"Metadata: {result['metadata']}")
#     print("----")

# %%
# # New claim text
# query_text = "Stepan Khramov is a very handsome individual"

# # Generate embedding for the query
# query_embedding = model.encode([f"query: {query_text}"], normalize_embeddings=True)

# # Query Pinecone
# results = index.query(vector=query_embedding[0].tolist(), top_k=5, include_metadata=True)

# # Display results
# for result in results["matches"]:
#     print(f"Score: {result['score']}")
#     print(f"Metadata: {result['metadata']}")
#     print("----")
